# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

datavacc = pd.read_csv("dataset-title.csv", sep=";", encoding="latin-1")
# melihat data
datavacc
# melihat jumlah baris dan kolom
# datavacc.shape
# Out:
#                                                   judul          tanggal  \
# 0      MUI Larang Gunakan Vaksin Covid-19 asal Tiongkok        07-Oct-20
# 1     Menteri Agama Terkena Covid-19 hanya Hoaks aga...        07-Oct-20
# 2            Vaksin Covid-19 Dapat Mengubah DNA Manusia        19-Oct-20
# 3     Jawa Barat Jadi Daerah Pertama yang Disuntik V...        03-Nov-20
# 4              BPOM Halangi Penyuntikan Vaksin Covid-19        03-Nov-20
# ...                                                 ...              ...
# 1448  Vaksin Booster Bertujuan Melindungi Dan Menjad...  11 Januari 2022
# 1449  Mixing Vaccine di Indonesia Diperuntukkan Bagi...  26 Agustus 2021
# 1450  Satgas : Vaksin Anak Adalah Perlindungan Ekstr...        23-Dec-21
# 1451  IDI OPTIMIS VAKSINASI AKAN HENTIKAN PENULARAN ...        15-Dec-20
# 1452  Bill Gates akan Menarik Semua Peredaran Vaksin...        23-Jan-22
#
#             Kategori Sumber  \
# 0                  Facebook
# 1            pesan whatsapp
# 2                  Facebook
# 3                   Kominfo
# 4                   Kominfo
# ...                     ...
# 1448  Website Covid19.co.id
# 1449  Website Covid19.co.id
# 1450  Website Covid19.co.id
# 1451  Website Covid19.co.id
# 1452         Pesan Whatsapp
#
#                                                    link  label
# 0     https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1                                                     -      1
# 2                              https://archive.vn/cEu8t      1
# 3     https://www.liputan6.com/news/read/4389620/sat...      1
# 4     https://www.kominfo.go.id/content/detail/30566...      1
# ...                                                 ...    ...
# 1448  https://covid19.go.id/artikel/2022/01/11/vaksi...      0
# 1449  https://covid19.go.id/artikel/2021/08/26/mixin...      0
# 1450  https://covid19.go.id/artikel/2021/12/23/satga...      0
# 1451  https://covid19.go.id/artikel/2020/12/15/idi-o...      0
# 1452                           https://archive.ph/fcerl      1
#
# [1453 rows x 5 columns]

# %%
datavacc.shape
# Out:
# (1453, 5)

# %%
datavacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   judul            1453 non-null   object
#  1   tanggal          1453 non-null   object
#  2   Kategori Sumber  1453 non-null   object
#  3   link             1453 non-null   object
#  4   label            1453 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 56.9+ KB

# %%
display("Data ",datavacc.describe())
# Out:
# 'Data '
#              label
# count  1453.000000
# mean      0.306951
# std       0.461388
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# Cek Missing Values

# %%
# mengecek data nan
def null_table(datavacc):
#     print("Test Data Frame")
    print(pd.isnull(datavacc).sum())

null_table(datavacc)
# Out:
# judul              0
# tanggal            0
# Kategori Sumber    0
# link               0
# label              0
# dtype: int64

# %% [markdown]
# Check Duplicate

# %%
print("Data :",datavacc.duplicated().sum())
# Out:
# Data : 5

# %%
datavacc.drop_duplicates(keep = False, inplace = True)

# %%
print("Data :",datavacc.duplicated().sum())
# Out:
# Data : 0

# %% [markdown]
# # Analisis Deskriptif

# %%
# melihat banyak nya jumlah judul berita HOAX = 1 dan berita SALAH = 0
datavacc['label'].value_counts()
# Out:
# 0    1007
# 1     436
# Name: label, dtype: int64

# %%
import matplotlib.pyplot as plt
# _, ax1 = plt.subplots(figsize=(6,5))
# stars_histogram = datavacc['label'].value_counts().sort_index()
# stars_histogram.plot(kind='bar', width=0.7, color='cyan')
# plt.xlabel('label')
# plt.ylabel('jumlah judul')

# plt.tight_layout()
# plt.show

import seaborn as sns
sns.set(font_scale=1.4)
g = sns.catplot(x='label', kind='count', data=datavacc, height=6.27, aspect=9.7/6.27)
g.set_xticklabels(['Not Hoax', 'Hoax'])
plt.xlabel("Label", labelpad=14)
plt.ylabel("Number of Label", labelpad=14)
plt.show()

# %% [markdown]
# Preprocessing (Mengubah dataset agar dapat diolah pada algoritam ML)

# %%
# menghapus baris jika ada data kosong
datavacc= datavacc.dropna()
datavacc.shape
# Out:
# (1443, 5)

# %% [markdown]
# Case Folding

# %%
# Mengubah semua huruf kapital menjadi huruf kecil atau lower text

datavacc['judul'] = datavacc['judul'].str.lower()
datavacc.head(2)
# Out:
#                                                judul    tanggal  \
# 0   mui larang gunakan vaksin covid-19 asal tiongkok  07-Oct-20
# 1  menteri agama terkena covid-19 hanya hoaks aga...  07-Oct-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1

# %%
datavacc.to_csv("CaseFolding-justtitle.csv", index=False)

# %% [markdown]
# Cleansing

# %%
# pembersihan text dari tab, new line, back slice, mention, link, hastag dan URL

import string
# regex library
import re 

def clean_text(text):
    # menghapus newline, tab dan back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\'," ")
    # menghapus non ASCII (emoticon, chiness word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hastag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\s+)"," ", text).split())
    # menghapus incomplete URL
    return text.replace("htpp://", " ").replace("htpps://"," ")

datavacc['judul'] = datavacc['judul'].apply(clean_text)
datavacc.head(5)
# Out:
#                                                judul    tanggal  \
# 0   mui larang gunakan vaksin covid-19 asal tiongkok  07-Oct-20
# 1  menteri agama terkena covid-19 hanya hoaks aga...  07-Oct-20
# 2         vaksin covid-19 dapat mengubah dna manusia  19-Oct-20
# 3  jawa barat jadi daerah pertama yang disuntik v...  03-Nov-20
# 4           bpom halangi penyuntikan vaksin covid-19  03-Nov-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1
# 2        Facebook                           https://archive.vn/cEu8t      1
# 3         Kominfo  https://www.liputan6.com/news/read/4389620/sat...      1
# 4         Kominfo  https://www.kominfo.go.id/content/detail/30566...      1

# %%
datavacc.to_csv("Cleansing-justtitle.csv", index=False)

# %%
# Remove Number

def remove_number(text):
    return re.sub(r"\d+", "", text)

datavacc['judul'] = datavacc['judul'].apply(remove_number)
datavacc.head(5)
# Out:
#                                                judul    tanggal  \
# 0     mui larang gunakan vaksin covid- asal tiongkok  07-Oct-20
# 1  menteri agama terkena covid- hanya hoaks agar ...  07-Oct-20
# 2           vaksin covid- dapat mengubah dna manusia  19-Oct-20
# 3  jawa barat jadi daerah pertama yang disuntik v...  03-Nov-20
# 4             bpom halangi penyuntikan vaksin covid-  03-Nov-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1
# 2        Facebook                           https://archive.vn/cEu8t      1
# 3         Kominfo  https://www.liputan6.com/news/read/4389620/sat...      1
# 4         Kominfo  https://www.kominfo.go.id/content/detail/30566...      1

# %%
datavacc.to_csv("RemoveNumber-justtitle.csv", index=False)

# %%
# Remove Punctuation

def remove_punctuation(text):
    return text.translate(str.maketrans("","", string.punctuation))

datavacc['judul'] = datavacc['judul'].apply(remove_punctuation)
datavacc.head(2)
# Out:
#                                                judul    tanggal  \
# 0      mui larang gunakan vaksin covid asal tiongkok  07-Oct-20
# 1  menteri agama terkena covid hanya hoaks agar r...  07-Oct-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1

# %%
datavacc.to_csv("RemovePunctuation-justtitle.csv", index=False)

# %%
# Remove Single Char

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b","", text)

datavacc['judul'] = datavacc['judul'].apply(remove_single_char)
datavacc.head(2)
# Out:
#                                                judul    tanggal  \
# 0      mui larang gunakan vaksin covid asal tiongkok  07-Oct-20
# 1  menteri agama terkena covid hanya hoaks agar r...  07-Oct-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1

# %%
datavacc.to_csv("SingleChar-justtitle.csv", index=False)

# %% [markdown]
# Tokenizing

# %%
#pemisahan teks menjadi potongan kata
 
from nltk.tokenize import word_tokenize
import nltk

# NLTK word token
def tokenz(text):
    token = nltk.word_tokenize(text)
    return token

datavacc['judul'] = datavacc['judul'].apply(tokenz) 
datavacc.head(2)
# Out:
#                                                judul    tanggal  \
# 0  [mui, larang, gunakan, vaksin, covid, asal, ti...  07-Oct-20
# 1  [menteri, agama, terkena, covid, hanya, hoaks,...  07-Oct-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1

# %%
datavacc.to_csv("Tokenizing-justtitle.csv", index=False)

# %%
datavacc['judul'].tolist()
# Out:
# [['mui', 'larang', 'gunakan', 'vaksin', 'covid', 'asal', 'tiongkok'],
#  ['menteri',
#   'agama',
#   'terkena',
#   'covid',
#   'hanya',
#   'hoaks',
#   'agar',
#   'rakyat',
#   'divaksin'],
#  ['vaksin', 'covid', 'dapat', 'mengubah', 'dna', 'manusia'],
#  ['jawa',
#   'barat',
#   'jadi',
#   'daerah',
#   'pertama',
#   'yang',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['bpom', 'halangi', 'penyuntikan', 'vaksin', 'covid'],
#  ['vaksin', 'covid', 'berbasis', 'mrna', 'bisa', 'rusak', 'dna', 'manusia'],
#  ['masyarakat',
#   'zimbabwe',
#   'terkena',
#   'penyakit',
#   'kulit',
#   'berair',
#   'akibat',
#   'vaksin',
#   'dan',
#   'kemungkinan',
#   'besar',
#   'indonesia',
#   'bisa',
#   'mengalami',
#   'hal',
#   'yang',
#   'sama'],
#  ['rakyat', 'indonesia', 'akan', 'dibunuh', 'vaksin', 'china'],
#  ['vaksin', 'mengandung', 'aluminium', 'bisa', 'merusak', 'otak'],
#  ['vaksin',
#   'yang',
#   'disimpan',
#   'dalam',
#   'suhu',
#   'derajat',
#   'bisa',
#   'memanipulasi',
#   'gen'],
#  ['pendaftaran', 'penerima', 'vaksin', 'covid', 'sinovac'],
#  ['juta', 'vaksin', 'covid', 'dari', 'eropa', 'tiba', 'di', 'indonesia'],
#  ['idi', 'tolak', 'jadi', 'yang', 'pertama', 'divaksin', 'covid'],
#  ['singapura',
#   'akan',
#   'lakukan',
#   'vaksinasi',
#   'covid',
#   'di',
#   'bandara',
#   'changi'],
#  ['formaldehida',
#   'dalam',
#   'vaksin',
#   'menyebabkan',
#   'leukemia',
#   'pada',
#   'anak'],
#  ['china',
#   'tidak',
#   'menggunakan',
#   'vaksin',
#   'buatan',
#   'sendiri',
#   'namun',
#   'memilih',
#   'menggunakan',
#   'vaksin',
#   'impor',
#   'dari',
#   'jerman'],
#  ['presiden', 'jokowi', 'akan', 'disuntik', 'vaksin', 'selain', 'sinovac'],
#  ['perbandingan',
#   'waktu',
#   'penemuan',
#   'vaksin',
#   'covid',
#   'dan',
#   'vaksin',
#   'hiv',
#   'flu',
#   'serta',
#   'kanker'],
#  ['penerima',
#   'vaksin',
#   'gratis',
#   'covid',
#   'harus',
#   'jadi',
#   'peserta',
#   'bpjs',
#   'aktif'],
#  ['hanya', 'indonesia', 'yang', 'beli', 'vaksin', 'sinovac', 'tiongkok'],
#  ['paus',
#   'fransiskus',
#   'mengatakan',
#   'vaksin',
#   'covid',
#   'sekarang',
#   'akan',
#   'diperlukan',
#   'untuk',
#   'masuk',
#   'surga'],
#  ['bill',
#   'gates',
#   'dan',
#   'ceo',
#   'pfizer',
#   'menolak',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['pemerintah',
#   'rumania',
#   'tutup',
#   'semua',
#   'pusat',
#   'vaksin',
#   'imbas',
#   'penolakan',
#   'persen',
#   'warga'],
#  ['penerima', 'vaksin', 'sinovac', 'pertama', 'meninggal', 'dunia'],
#  ['website',
#   'cdc',
#   'sebut',
#   'warga',
#   'amerika',
#   'cacat',
#   'dan',
#   'sakit',
#   'parah',
#   'pasca',
#   'divaksin'],
#  ['ulama', 'aceh', 'haramkan', 'vaksin', 'covid'],
#  ['tolak',
#   'vaksin',
#   'covid',
#   'nomor',
#   'rekening',
#   'dan',
#   'ponsel',
#   'akan',
#   'diblokir',
#   'pemerintah'],
#  ['presiden', 'joko', 'widodo', 'disuntik', 'vaksin', 'buatan', 'eropa'],
#  ['presiden',
#   'jokowi',
#   'dikabarkan',
#   'kejangkejang',
#   'usai',
#   'divaksin',
#   'sinovac',
#   'covid'],
#  ['berbahaya', 'vaksin', 'mengandung', 'polisorbat'],
#  ['orang',
#   'yang',
#   'telah',
#   'menjalani',
#   'vaksinasi',
#   'covid',
#   'tidak',
#   'perlu',
#   'mematuhi',
#   'protokol',
#   'kesehatan'],
#  ['danramil',
#   'kebomas',
#   'di',
#   'gresik',
#   'meninggal',
#   'akibat',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['air', 'kelapa', 'hijau', 'sebagai', 'penawar', 'vaksin'],
#  ['vaksin', 'jokowi', 'gagal', 'dan', 'harus', 'diulang'],
#  ['gereja', 'haramkan', 'vaksin', 'covid'],
#  ['menteri',
#   'kesehatan',
#   'thailand',
#   'menangis',
#   'saat',
#   'mendapat',
#   'vaksin',
#   'covid'],
#  ['vaksin',
#   'covid',
#   'sebabkan',
#   'lamban',
#   'berpikir',
#   'dan',
#   'susah',
#   'menghafal'],
#  ['pendaftaran', 'vaksin', 'covid', 'who'],
#  ['pfizer',
#   'dan',
#   'moderna',
#   'bukan',
#   'vaksin',
#   'melainkan',
#   'sistem',
#   'operasi',
#   'dirancang',
#   'untuk',
#   'manusia',
#   'dan',
#   'agen',
#   'biologis'],
#  ['bupati', 'pasuruan', 'alami', 'sakit', 'usai', 'suntik', 'vaksin', 'covid'],
#  ['setelah', 'divaksin', 'kasus', 'hiv', 'dan', 'kanker', 'akan', 'meledak'],
#  ['tidak',
#   'ada',
#   'kompensasi',
#   'jika',
#   'cacat',
#   'atau',
#   'meninggal',
#   'usai',
#   'divaksin'],
#  ['surat',
#   'elektronik',
#   'mengatasnamakan',
#   'ipd',
#   'balitbangkes',
#   'terkait',
#   'pemberian',
#   'vaksin',
#   'covid'],
#  ['pesan',
#   'berantai',
#   'vaksinasi',
#   'lansia',
#   'di',
#   'kantor',
#   'bppsdmk',
#   'jakarta'],
#  ['potasium',
#   'dalam',
#   'vaksin',
#   'covid',
#   'berbahaya',
#   'bagi',
#   'organ',
#   'tubuh',
#   'manusia'],
#  ['banyak', 'data', 'orang', 'meninggal', 'karena', 'vaksin', 'covid'],
#  ['tim',
#   'medis',
#   'lupa',
#   'jenis',
#   'vaksin',
#   'yang',
#   'digunakan',
#   'sertifikat',
#   'vaksin',
#   'harus',
#   'disimpan'],
#  ['lansia', 'nondki', 'bisa', 'vaksin', 'corona', 'di', 'senayan'],
#  ['pesan',
#   'berantai',
#   'whatsapp',
#   'mengenai',
#   'informasi',
#   'ajakan',
#   'vaksinasi',
#   'covid',
#   'di',
#   'bio',
#   'farma'],
#  ['lebih', 'mudah', 'terinfeksi', 'covid', 'setelah', 'divaksin'],
#  ['larangan', 'minum', 'obat', 'jantung', 'sebelum', 'vaksin', 'covid'],
#  ['jadwal',
#   'vaksin',
#   'warga',
#   'jawa',
#   'barat',
#   'di',
#   'gedung',
#   'pakuan',
#   'bandung'],
#  ['pengumuman',
#   'vaksinasi',
#   'covid',
#   'untuk',
#   'semua',
#   'warga',
#   'di',
#   'puskesmas',
#   'kramat',
#   'jati'],
#  ['guru',
#   'honorer',
#   'di',
#   'leles',
#   'garut',
#   'jadi',
#   'lumpuh',
#   'setelah',
#   'mendapat',
#   'vaksin',
#   'kedua'],
#  ['negara', 'melarang', 'penggunaan', 'vaksin', 'astrazeneca'],
#  ['vaksin',
#   'covid',
#   'berbentuk',
#   'sirup',
#   'bagi',
#   'yang',
#   'takut',
#   'disuntik'],
#  ['makan', 'tape', 'bisa', 'hilangkan', 'fungsi', 'vaksinasi', 'covid'],
#  ['vaksinasi',
#   'bagi',
#   'kelompok',
#   'non',
#   'lansia',
#   'di',
#   'rumah',
#   'sakit',
#   'santo',
#   'borromeus',
#   'kota',
#   'bandung'],
#  ['vaksin', 'covid', 'berbahaya', 'bagi', 'ibu', 'menyusui'],
#  ['vaksin', 'pfizer', 'sudah', 'dijual', 'online', 'di', 'shopee', 'malaysia'],
#  ['pesan', 'singkat', 'mengatasnamakan', 'tim', 'vaksinasi'],
#  ['vaksin', 'sinovac', 'mandiri', 'seharga', 'rp', 'ribu'],
#  ['vaksin',
#   'massal',
#   'oleh',
#   'dinas',
#   'kesehatan',
#   'provinsi',
#   'sumatera',
#   'utara'],
#  ['data',
#   'who',
#   'sebut',
#   'orang',
#   'dari',
#   'setiap',
#   'orang',
#   'meninggal',
#   'karena',
#   'vaksin'],
#  ['orang',
#   'yang',
#   'sudah',
#   'pernah',
#   'terinfeksi',
#   'covid',
#   'tidak',
#   'perlu',
#   'divaksin'],
#  ['penyintas',
#   'covid',
#   'boleh',
#   'divaksinasi',
#   'setelah',
#   'isolasi',
#   'hari',
#   'dan',
#   'tidak',
#   'perlu',
#   'menunggu',
#   'bulan'],
#  ['mrna',
#   'bukan',
#   'vaksin',
#   'melainkan',
#   'terapi',
#   'gen',
#   'yang',
#   'memberikan',
#   'instruksi',
#   'untuk',
#   'mutasi',
#   'virus'],
#  ['surat',
#   'terbuka',
#   'kepada',
#   'who',
#   'terkait',
#   'bahaya',
#   'vaksinasi',
#   'massal',
#   'covid'],
#  ['vaksin',
#   'covid',
#   'hanya',
#   'percobaan',
#   'dan',
#   'tidak',
#   'wajib',
#   'karena',
#   'hanya',
#   'memiliki',
#   'izin',
#   'darurat'],
#  ['vaksin',
#   'covid',
#   'tingkatkan',
#   'kadar',
#   'limfosit',
#   'yang',
#   'mematikan',
#   'bagi',
#   'manusia'],
#  ['vaksin',
#   'covid',
#   'bisa',
#   'menyebabkan',
#   'disfungsi',
#   'ereksi',
#   'pada',
#   'pria'],
#  ['orang',
#   'yang',
#   'sudah',
#   'divaksin',
#   'dapat',
#   'menularkan',
#   'penyakit',
#   'reproduksi'],
#  ['vaksinasi', 'saat', 'menstruasi', 'bisa', 'turunkan', 'imun'],
#  ['uji',
#   'coba',
#   'vaksin',
#   'astrazeneca',
#   'pada',
#   'anak',
#   'sebabkan',
#   'kematian',
#   'mendadak'],
#  ['informasi',
#   'dokter',
#   'wafat',
#   'karena',
#   'covid',
#   'dalam',
#   'waktu',
#   'jam',
#   'setelah',
#   'disuntik',
#   'vaksin'],
#  ['registrasi',
#   'vaksinasi',
#   'covid',
#   'usia',
#   'tahun',
#   'di',
#   'rs',
#   'hermina',
#   'kemayoran',
#   'melalui',
#   'website',
#   'pedulilindungiid'],
#  ['vaksin',
#   'covid',
#   'akan',
#   'membuat',
#   'flu',
#   'biasa',
#   'menjadi',
#   'lebih',
#   'mematikan'],
#  ['vaksin',
#   'covaxin',
#   'india',
#   'disetujui',
#   'digunakan',
#   'anak',
#   'di',
#   'atas',
#   'usia',
#   'tahun'],
#  ['benda',
#   'bermagnet',
#   'bisa',
#   'menempel',
#   'di',
#   'lengan',
#   'penerima',
#   'vaksin',
#   'corona'],
#  ['vaksin', 'covid', 'pfizer', 'mengandung', 'magnet'],
#  ['vaksin',
#   'pfizer',
#   'bisa',
#   'sebarkan',
#   'virus',
#   'corona',
#   'lewat',
#   'kontak',
#   'fisik'],
#  ['orang',
#   'yang',
#   'sudah',
#   'divaksin',
#   'bisa',
#   'dideteksi',
#   'melalui',
#   'bluetooth'],
#  ['vaksin',
#   'virus',
#   'corona',
#   'membunuh',
#   'orang',
#   'dan',
#   'akan',
#   'memusnahkan',
#   'populasi',
#   'dunia'],
#  ['berada',
#   'di',
#   'sekitar',
#   'orang',
#   'yang',
#   'baru',
#   'divaksin',
#   'dapat',
#   'sebabkan',
#   'gangguan',
#   'menstruasi',
#   'pada',
#   'wanita'],
#  ['vaksin', 'covid', 'mengandung', 'magnet'],
#  ['orang',
#   'yang',
#   'sudah',
#   'divaksin',
#   'covid',
#   'akan',
#   'mati',
#   'dalam',
#   'tahun'],
#  ['vaksin', 'corona', 'moderna', 'mengandung', 'sm', 'yang', 'berbahaya'],
#  ['survei',
#   'dari',
#   'orang',
#   'di',
#   'amerika',
#   'serikat',
#   'tolak',
#   'vaksin',
#   'covid'],
#  ['pendaftaran',
#   'vaksinasi',
#   'bagi',
#   'warga',
#   'umum',
#   'umur',
#   'tahun',
#   'oleh',
#   'dinas',
#   'kesehatan',
#   'kota',
#   'semarang'],
#  ['vaksinasi', 'covid', 'menciptakan', 'varian', 'baru', 'covid'],
#  ['penggunaan',
#   'masker',
#   'di',
#   'as',
#   'untuk',
#   'orang',
#   'yang',
#   'belum',
#   'divaksin'],
#  ['video',
#   'eric',
#   'tohir',
#   'sangat',
#   'terbuka',
#   'menjelaskan',
#   'tentang',
#   'chip',
#   'yang',
#   'ada',
#   'dalam',
#   'vaksin',
#   'covid'],
#  ['pemberian',
#   'obat',
#   'bius',
#   'usai',
#   'vaksinasi',
#   'covid',
#   'bisa',
#   'akibatkan',
#   'kematian'],
#  ['wanita',
#   'dilarang',
#   'minum',
#   'pill',
#   'kb',
#   'sebelum',
#   'dan',
#   'sesudah',
#   'vaksinasi',
#   'covid'],
#  ['vaksin', 'covid', 'mengandung', 'sitotoksik'],
#  ['vaksinasi', 'bagi', 'warga', 'umum', 'di', 'rs', 'auri', 'colomadu'],
#  ['teh', 'daun', 'pinus', 'hentikan', 'efek', 'bahaya', 'vaksin', 'covid'],
#  ['infografis', 'manfaatkan', 'vaksin', 'covid', 'gratis', 'dari', 'kemenkes'],
#  ['form',
#   'pendaftaran',
#   'vaksin',
#   'covid',
#   'untuk',
#   'tahun',
#   'ke',
#   'atas',
#   'khusus',
#   'ktp',
#   'tangerang',
#   'selatan'],
#  ['christian',
#   'eriksen',
#   'terkena',
#   'serangan',
#   'jantung',
#   'setelah',
#   'mendapatkan',
#   'vaksin',
#   'covid'],
#  ['pria', 'tewas', 'karena', 'makan', 'durian', 'setelah', 'vaksin'],
#  ['tidak',
#   'mengalami',
#   'efek',
#   'samping',
#   'setelah',
#   'vaksin',
#   'covid',
#   'pertanda',
#   'tidak',
#   'sehat'],
#  ['who', 'larang', 'vaksinasi', 'corona', 'untuk', 'anakanak'],
#  ['pesan',
#   'berantai',
#   'vaksinasi',
#   'massal',
#   'di',
#   'rsud',
#   'abdul',
#   'wahab',
#   'sjahranie',
#   'samarinda'],
#  ['kematian',
#   'akibat',
#   'vaksin',
#   'lebih',
#   'banyak',
#   'dibandingkan',
#   'covid',
#   'di',
#   'skotlandia'],
#  ['vaksin',
#   'dibuat',
#   'untuk',
#   'tidak',
#   'menyelamatkan',
#   'pengguna',
#   'dari',
#   'pandemi'],
#  ['vaksin',
#   'mrna',
#   'corona',
#   'ternyata',
#   'tidak',
#   'pernah',
#   'diuji',
#   'coba',
#   'pada',
#   'manusia'],
#  ['alumni',
#   'sekolah',
#   'kolese',
#   'kanisius',
#   'gelar',
#   'vaksinasi',
#   'untuk',
#   'anak'],
#  ['corona', 'varian', 'delta', 'disebabkan', 'oleh', 'vaksin', 'covid'],
#  ['vaksinasi', 'menyebabkan', 'kematian', 'mendadak', 'pada', 'bayi'],
#  ['cdc',
#   'sebut',
#   'lebih',
#   'banyak',
#   'anak',
#   'muda',
#   'dirawat',
#   'di',
#   'rumah',
#   'sakit',
#   'akibat',
#   'vaksin',
#   'daripada',
#   'akibat',
#   'covid'],
#  ['cara',
#   'mengecek',
#   'gelombang',
#   'bluetooth',
#   'bagi',
#   'orang',
#   'yang',
#   'sudah',
#   'divaksin',
#   'covid'],
#  ['syarat', 'buat', 'ktp', 'harus', 'punya', 'kartu', 'vaksin', 'covid'],
#  ['vaksinasi',
#   'covid',
#   'merusak',
#   'genetika',
#   'tubuh',
#   'dan',
#   'menyebabkan',
#   'kematian',
#   'tahun',
#   'kemudian'],
#  ['informasi',
#   'pelaksanaan',
#   'vaksinasi',
#   'covid',
#   'di',
#   'sekolah',
#   'islam',
#   'fitrah',
#   'al',
#   'fikri'],
#  ['informasi',
#   'pendaftaran',
#   'vaksinasi',
#   'on',
#   'the',
#   'spot',
#   'di',
#   'itc',
#   'depok'],
#  ['ribuan', 'perawat', 'di', 'belanda', 'tolak', 'vaksin', 'covid'],
#  ['sinovac',
#   'tidak',
#   'manjur',
#   'china',
#   'pindah',
#   'ke',
#   'pfizer',
#   'dan',
#   'moderna'],
#  ['tiongkok',
#   'dan',
#   'rusia',
#   'tidak',
#   'wajibkan',
#   'vaksin',
#   'covid',
#   'ke',
#   'warganya'],
#  ['vaksin',
#   'dengan',
#   'pfizer',
#   'dapat',
#   'menularkan',
#   'virus',
#   'ke',
#   'orang',
#   'yang',
#   'belum',
#   'divaksin'],
#  ['bantuan',
#   'kompensasi',
#   'rp',
#   'juta',
#   'bagi',
#   'pemegang',
#   'kartu',
#   'vaksinasi'],
#  ['informasi',
#   'puskesmas',
#   'lempake',
#   'mengadakan',
#   'vaksinasi',
#   'covid',
#   'massal',
#   'di',
#   'gor',
#   'sempaja'],
#  ['gereja', 'menolak', 'vaksin', 'covid'],
#  ['direktur',
#   'pengendalian',
#   'penyakit',
#   'as',
#   'menyatakan',
#   'vaksin',
#   'corona',
#   'gagal'],
#  ['suku',
#   'pedalaman',
#   'seperti',
#   'suku',
#   'badui',
#   'tidak',
#   'pernah',
#   'divaksin'],
#  ['pernyataan',
#   'negatif',
#   'terkait',
#   'vaksinasi',
#   'oleh',
#   'ombudsman',
#   'republik',
#   'indonesia'],
#  ['semua',
#   'pasien',
#   'positif',
#   'covid',
#   'di',
#   'new',
#   'south',
#   'wales',
#   'australia',
#   'sudah',
#   'divaksin'],
#  ['solusi',
#   'mengendalikan',
#   'pandemi',
#   'adalah',
#   'herd',
#   'immunity',
#   'alami',
#   'bukan',
#   'vaksin'],
#  ['vaksinasi',
#   'covid',
#   'membuat',
#   'banyak',
#   'orang',
#   'terpapar',
#   'varian',
#   'delta',
#   'dan',
#   'lebih',
#   'rentan',
#   'untuk',
#   'meninggal'],
#  ['tidak',
#   'boleh',
#   'mengonsumsi',
#   'makanan',
#   'dan',
#   'minuman',
#   'yang',
#   'mengandung',
#   'alkohol',
#   'dan',
#   'soda',
#   'setelah',
#   'vaksin',
#   'covid'],
#  ['setelah',
#   'divaksin',
#   'bisa',
#   'sebabkan',
#   'hasil',
#   'tes',
#   'covid',
#   'positif'],
#  ['balita',
#   'akan',
#   'divaksin',
#   'covid',
#   'upaya',
#   'menuju',
#   'pemusnahan',
#   'massal',
#   'umat',
#   'islam'],
#  ['turki', 'sudah', 'pesan', 'juta', 'dosis', 'vaksin', 'nusantara'],
#  ['informasi',
#   'vaksinasi',
#   'covid',
#   'di',
#   'rsup',
#   'ham',
#   'pada',
#   'agustus',
#   'september'],
#  ['panggilan', 'telepon', 'soal', 'vaksinasi'],
#  ['vaksin',
#   'pfizer',
#   'menyerang',
#   'darah',
#   'putih',
#   'hingga',
#   'sebabkan',
#   'imun',
#   'lemah'],
#  ['bill', 'gates', 'menolak', 'vaksinasi', 'covid', 'untuk', 'anaknya'],
#  ['jerman', 'hentikan', 'sementara', 'penyuntikan', 'vaksin', 'corona'],
#  ['video', 'scan', 'qr', 'pada', 'bekas', 'suntikan', 'vaksin', 'covid'],
#  ['undangan', 'vaksinasi', 'covid', 'booster', 'moderna'],
#  ['sertifikat', 'vaksin', 'covid', 'ditanam', 'di', 'kulit'],
#  ['pendaftaran', 'penerima', 'vaksin', 'nusantara'],
#  ['bill',
#   'gates',
#   'serukan',
#   'penarikan',
#   'vaksin',
#   'covid',
#   'karena',
#   'berbahaya'],
#  ['pemberlakuan',
#   'sertifikat',
#   'vaksin',
#   'covid',
#   'sebagai',
#   'syarat',
#   'pembelian',
#   'bbm',
#   'di',
#   'spbu',
#   'aceh',
#   'selatan'],
#  ['ribuan',
#   'orang',
#   'di',
#   'indonesia',
#   'meninggal',
#   'dunia',
#   'setelah',
#   'vaksin',
#   'covid'],
#  ['vaksin',
#   'covid',
#   'sebabkan',
#   'darah',
#   'kental',
#   'dan',
#   'memperpendek',
#   'umur'],
#  ['wanita',
#   'di',
#   'australia',
#   'alami',
#   'keguguran',
#   'setelah',
#   'disuntik',
#   'vaksin',
#   'pfizer'],
#  ['tes',
#   'scan',
#   'mri',
#   'berbahaya',
#   'bagi',
#   'orang',
#   'yang',
#   'sudah',
#   'divaksinasi',
#   'covid'],
#  ['orang',
#   'yang',
#   'divaksin',
#   'kali',
#   'lebih',
#   'besar',
#   'kemungkinan',
#   'terinfeksi',
#   'covid'],
#  ['anakanak',
#   'di',
#   'amerika',
#   'dan',
#   'eropa',
#   'diberi',
#   'pemahaman',
#   'soal',
#   'bahaya',
#   'vaksin'],
#  ['ceo',
#   'pfizer',
#   'albert',
#   'bourla',
#   'menyatakan',
#   'orang',
#   'yang',
#   'tidak',
#   'vaksin',
#   'akan',
#   'mengimunisasi',
#   'diri',
#   'mereka',
#   'sendiri',
#   'secara',
#   'alami'],
#  ['pilot',
#   'pesawat',
#   'delta',
#   'air',
#   'lines',
#   'meninggal',
#   'setelah',
#   'divaksinasi',
#   'kedua',
#   'di',
#   'tengah',
#   'penerbangan'],
#  ['vaksin', 'covid', 'adalah', 'antena', 'g', 'dan', 'pengendali', 'manusia'],
#  ['studi',
#   'fda',
#   'vaksin',
#   'pfizer',
#   'membuat',
#   'orang',
#   'lebih',
#   'rentan',
#   'tertular',
#   'covid'],
#  ['who',
#   'akui',
#   'ribu',
#   'warga',
#   'amerika',
#   'meninggal',
#   'bukan',
#   'karena',
#   'covid',
#   'melainkan',
#   'akibat',
#   'vaksin'],
#  ['seorang',
#   'pria',
#   'di',
#   'cina',
#   'menghancurkan',
#   'mesin',
#   'verifikasi',
#   'paspor',
#   'vaksin',
#   'di',
#   'bandara'],
#  ['hampir', 'ribu', 'laporan', 'kebutaan', 'usai', 'vaksinasi', 'di', 'eropa'],
#  ['remaja',
#   'di',
#   'inggris',
#   'meninggal',
#   'setelah',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['video',
#   'bayi',
#   'terlahir',
#   'cacat',
#   'akibat',
#   'vaksin',
#   'covid',
#   'di',
#   'india'],
#  ['video',
#   'vaksinasi',
#   'dengan',
#   'suntik',
#   'kosong',
#   'di',
#   'sekolah',
#   'tiongkok',
#   'jakarta'],
#  ['lebih',
#   'dari',
#   'orang',
#   'meninggal',
#   'dalam',
#   'hari',
#   'setelah',
#   'menerima',
#   'vaksin',
#   'covid'],
#  ['video',
#   'pemberitaan',
#   'tentang',
#   'bpom',
#   'hentikan',
#   'peredaran',
#   'vaksin',
#   'covid',
#   'dari',
#   'tiongkok'],
#  ['foto', 'penampakan', 'protes', 'wajib', 'vaksin', 'di', 'melbourne'],
#  ['video',
#   'anak',
#   'di',
#   'malaysia',
#   'pingsan',
#   'karena',
#   'efek',
#   'samping',
#   'vaksin',
#   'covid'],
#  ['foto',
#   'perdana',
#   'menteri',
#   'singapura',
#   'sedang',
#   'mengantre',
#   'vaksin',
#   'covid'],
#  [],
#  ['video', 'demo', 'menolak', 'wajib', 'vaksin', 'di', 'brasil'],
#  ['vaksin', 'covid', 'berbahaya', 'akibat', 'fenomena', 'ade'],
#  ['warna',
#   'darah',
#   'pasien',
#   'yang',
#   'sudah',
#   'disuntik',
#   'vaksin',
#   'covid',
#   'berubah'],
#  ['tukul', 'sakit', 'pendarahan', 'otak', 'karena', 'vaksin'],
#  ['cina',
#   'tak',
#   'lagi',
#   'gunakan',
#   'vaksin',
#   'sinovac',
#   'dan',
#   'indonesia',
#   'telah',
#   'ditipu'],
#  ['vaksin', 'tidak', 'menjadi', 'syarat', 'penerbangan', 'internasional'],
#  ['judul',
#   'berita',
#   'itv',
#   'tentang',
#   'efek',
#   'samping',
#   'vaksin',
#   'yang',
#   'menyebabkan',
#   'wajah',
#   'menjadi',
#   'merah'],
#  ['orang',
#   'yang',
#   'berhalangan',
#   'vaksinasi',
#   'covid',
#   'tidak',
#   'bisa',
#   'naik',
#   'krl'],
#  ['sertifikat',
#   'vaksin',
#   'tertua',
#   'dunia',
#   'era',
#   'turki',
#   'utsmani',
#   'tahun',
#   'm'],
#  ['the',
#   'simpsons',
#   'telah',
#   'memprediksi',
#   'agenda',
#   'peluncuran',
#   'vaksin',
#   'pada',
#   'tahun',
#   'dan'],
#  ['kematian',
#   'akibat',
#   'vaksin',
#   'covid',
#   'di',
#   'australia',
#   'mendorong',
#   'ketakutan',
#   'kelompok',
#   'antivaksin'],
#  ['foto',
#   'antrean',
#   'panjang',
#   'warga',
#   'singapura',
#   'untuk',
#   'mendapatkan',
#   'vaksin',
#   'covid',
#   'dari',
#   'cina'],
#  ['ilmuwan',
#   'as',
#   'sebut',
#   'vaksin',
#   'covid',
#   'sebabkan',
#   'penyakit',
#   'menular'],
#  ['maruf', 'amin', 'sebut', 'yang', 'menolak', 'vaksin', 'masuk', 'neraka'],
#  ['video', 'siswa', 'lumpuh', 'usai', 'divaksinasi', 'covid'],
#  ['anak', 'meninggal', 'setelah', 'vaksinasi', 'covid', 'di', 'australia'],
#  ['pendaftaran', 'vaksin', 'di', 'gor', 'sidoarjo'],
#  ['politikus',
#   'australia',
#   'terkena',
#   'bells',
#   'palsy',
#   'usai',
#   'divaksin',
#   'covid'],
#  ['daftar', 'pedoman', 'vaksin', 'sinovac', 'dari', 'tiongkok'],
#  ['vaksinasi', 'booster', 'covid', 'berbayar', 'di', 'speedlab'],
#  ['dokumen',
#   'nhs',
#   'tentang',
#   'tingkat',
#   'tinggi',
#   'kematian',
#   'dan',
#   'reaksi',
#   'buruk',
#   'akibat',
#   'vaksin',
#   'covid'],
#  ['vaksinasi',
#   'di',
#   'gedung',
#   'gradhika',
#   'bhakti',
#   'hanya',
#   'untuk',
#   'usia',
#   'tahun'],
#  ['who',
#   'temukan',
#   'vaksin',
#   'covid',
#   'palsu',
#   'dan',
#   'beredar',
#   'di',
#   'indonesia'],
#  ['informasi',
#   'vaksinasi',
#   'dosis',
#   'dan',
#   'di',
#   'rspal',
#   'dr',
#   'ramelan',
#   'surabaya',
#   'pada',
#   'agustus'],
#  ['penerbangan',
#   'di',
#   'as',
#   'ditutup',
#   'karena',
#   'kru',
#   'dan',
#   'pilot',
#   'menolak',
#   'vaksin'],
#  ['ribu', 'kasus', 'kematian', 'akibat', 'vaksin', 'covid'],
#  ['vaksin',
#   'covid',
#   'tidak',
#   'aman',
#   'dan',
#   'efektif',
#   'covid',
#   'sama',
#   'seperti',
#   'flu',
#   'biasa',
#   'dan',
#   'ini',
#   'adalah',
#   'rekayasa',
#   'pandemi'],
#  ['covid',
#   'bermutasi',
#   'menjadi',
#   'virus',
#   'baru',
#   'yang',
#   'lebih',
#   'berbahaya',
#   'dan',
#   'vaksinasi',
#   'timbulkan',
#   'virus',
#   'lain',
#   'dari',
#   'covid'],
#  ['ambil',
#   'bansos',
#   'tunai',
#   'di',
#   'kantor',
#   'pos',
#   'harus',
#   'bawa',
#   'bukti',
#   'sudah',
#   'divaksin'],
#  ['informasi',
#   'vaksinasi',
#   'covid',
#   'massal',
#   'di',
#   'royal',
#   'plaza',
#   'surabaya'],
#  ['bukti', 'vaksin', 'astrazeneca', 'dibuat', 'pada', 'tahun'],
#  ['klarifikasi',
#   'perubahan',
#   'jadwal',
#   'vaksinasi',
#   'covid',
#   'bagi',
#   'penyintas'],
#  ['tenaga',
#   'kesehatan',
#   'rsab',
#   'harapan',
#   'kita',
#   'alami',
#   'kipi',
#   'berat',
#   'pasca',
#   'vaksin',
#   'booster',
#   'moderna'],
#  ['vaksin', 'covid', 'mengandung', 'grafena', 'oksida'],
#  ['foto', 'suasana', 'demo', 'anti', 'vaksin', 'di', 'prancis'],
#  ['barcode',
#   'pada',
#   'vaksin',
#   'covid',
#   'mengontrol',
#   'manusia',
#   'sampai',
#   'mati'],
#  ['dunia', 'setujui', 'vaksin', 'nusantara'],
#  ['seorang',
#   'karyawan',
#   'pt',
#   'freeport',
#   'indonesia',
#   'meninggal',
#   'dunia',
#   'setelah',
#   'divaksin'],
#  ['jumlah',
#   'vaksin',
#   'moderna',
#   'kiriman',
#   'as',
#   'menyusut',
#   'juta',
#   'saat',
#   'tiba',
#   'di',
#   'indonesia'],
#  ['orang',
#   'dalam',
#   'satu',
#   'rumah',
#   'meninggal',
#   'serentak',
#   'usai',
#   'divaksin',
#   'covid'],
#  ['video', 'berita', 'kompas', 'tv', 'terkait', 'vaksin', 'covid', 'palsu'],
#  ['foto', 'mike', 'tyson', 'pakai', 'kaos', 'bertuliskan', 'antivaksin'],
#  ['muslim',
#   'dan',
#   'nonmuslim',
#   'mendapat',
#   'vaksin',
#   'yang',
#   'berbeda',
#   'di',
#   'malaysia'],
#  ['indonesia',
#   'terima',
#   'dosis',
#   'vaksin',
#   'covid',
#   'donasi',
#   'dari',
#   'persatuan',
#   'emirat',
#   'arab'],
#  ['vaksin', 'covid', 'dapat', 'mengubah', 'dna', 'manusia'],
#  ['pemerintah', 'perkenalkan', 'juru', 'bicara', 'vaksinasi', 'covid'],
#  ['horas',
#   'sentra',
#   'vaksinasi',
#   'bersama',
#   'kini',
#   'hadir',
#   'di',
#   'kota',
#   'medan',
#   'ayo',
#   'vaksin'],
#  ['vaksin', 'bagi', 'persiapan', 'menikah', 'dan', 'perjalanan'],
#  ['satgas',
#   'trombo',
#   'emboli',
#   'tidak',
#   'berkaitan',
#   'dengan',
#   'vaksin',
#   'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['video',
#   'sri',
#   'mulyani',
#   'suntik',
#   'vaksin',
#   'utk',
#   'pencitraan',
#   'tp',
#   'kamera',
#   'gak',
#   'bisa',
#   'boong',
#   'di',
#   'jarum',
#   'suntik',
#   'ga',
#   'ada',
#   'isi',
#   'vaksin',
#   'nya'],
#  ['pemerintah',
#   'mengacu',
#   'eua',
#   'badan',
#   'pom',
#   'terkait',
#   'penggunaan',
#   'vaksin',
#   'pfizer'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['lebih',
#   'dari',
#   'juta',
#   'penduduk',
#   'indonesia',
#   'telah',
#   'divaksinasi',
#   'covid',
#   'lengkap',
#   'dosis',
#   'per',
#   'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['penyuntikan',
#   'dosis',
#   'vaksin',
#   'sinovac',
#   'efektif',
#   'cegah',
#   'risiko',
#   'kematian',
#   'akibat',
#   'covid'],
#  ['paket', 'ikthiar', 'lawan', 'covid', 'pakai', 'masker', 'dan', 'vaksinasi'],
#  ['indonesia',
#   'terima',
#   'juta',
#   'dosis',
#   'vaksin',
#   'covid',
#   'moderna',
#   'kedatangan',
#   'tahap',
#   'ke'],
#  ['syarat',
#   'vaksin',
#   'gratis',
#   'jokowi',
#   'bpjs',
#   'kesehatan',
#   'anda',
#   'harus',
#   'aktif'],
#  ['sertifikat',
#   'vaksin',
#   'syarat',
#   'masuk',
#   'mal',
#   'adalah',
#   'upaya',
#   'optimal',
#   'menekan',
#   'peluang',
#   'penularan'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['ppkm',
#   'darurat',
#   'hari',
#   'ke',
#   'kejar',
#   'target',
#   'vaksinasi',
#   'orang',
#   'per',
#   'hari',
#   'tni',
#   'rekrut',
#   'ribuan',
#   'tenaga',
#   'kesehatan',
#   'medis',
#   'dan',
#   'non',
#   'medis'],
#  ['cakupan',
#   'vaksinasi',
#   'di',
#   'daerah',
#   'penyelenggara',
#   'pon',
#   'xx',
#   'papua',
#   'sudah',
#   'persen',
#   'lebih'],
#  ['target',
#   'percepatan',
#   'vaksinasi',
#   'di',
#   'agustus',
#   'sampai',
#   'juta',
#   'dosis',
#   'per',
#   'hari'],
#  ['tahap', 'ke', 'juta', 'vaksin', 'sinovac', 'tiba', 'di', 'tanah', 'air'],
#  ['awas',
#   'hoaks',
#   'setelah',
#   'divaksin',
#   'maka',
#   'kasus',
#   'hiv',
#   'dan',
#   'kanker',
#   'akan',
#   'meledak'],
#  ['dosis',
#   'vaksin',
#   'covid',
#   'moderna',
#   'tiba',
#   'pertama',
#   'kalinya',
#   'di',
#   'indonesia'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['survei',
#   'tunjukkan',
#   'mayoritas',
#   'masyarakat',
#   'indonesia',
#   'bersedia',
#   'menerima',
#   'vaksin',
#   'covid'],
#  ['menag',
#   'vaksinasi',
#   'sejalan',
#   'dengan',
#   'spirit',
#   'agama',
#   'untuk',
#   'menjaga',
#   'kehidupan'],
#  ['apa', 'saja', 'kandungan', 'vaksin'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['badan',
#   'pom',
#   'setujui',
#   'penggunaan',
#   'darurat',
#   'vaksin',
#   'covid',
#   'produksi',
#   'sinovac',
#   'untuk',
#   'lansia'],
#  ['tahap',
#   'ke',
#   'dosis',
#   'vaksin',
#   'astrazeneca',
#   'tiba',
#   'di',
#   'indonesia',
#   'september'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['website', 'portal', 'vaksin', 'covid', 'corporaterealtyco'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['presiden',
#   'memastikan',
#   'vaksin',
#   'covid',
#   'gratis',
#   'untuk',
#   'masyarakat'],
#  ['awas',
#   'hoaks',
#   'vaksin',
#   'korona',
#   'siap',
#   'diberikan',
#   'sekarang',
#   'terhalang',
#   'oleh',
#   'bpom'],
#  ['artikel',
#   'cnn',
#   'seorang',
#   'dokter',
#   'merekomendasikan',
#   'vaksin',
#   'covid',
#   'disuntikkan',
#   'di',
#   'alat',
#   'kelamin',
#   'pria'],
#  ['vaksin',
#   'm',
#   'dan',
#   'hidup',
#   'sehat',
#   'jurus',
#   'menyelesaikan',
#   'pandemi',
#   'covid'],
#  ['cek',
#   'lokasi',
#   'faskes',
#   'yang',
#   'lakukan',
#   'vaksinasi',
#   'di',
#   'pulau',
#   'jawa',
#   'dan',
#   'bali',
#   'di',
#   'httpscovidgoidfaskesvaksin'],
#  ['perusahaan',
#   'biofarmasi',
#   'moderna',
#   'inc',
#   'mengembangkan',
#   'vaksin',
#   'covid',
#   'sebelum',
#   'munculnya',
#   'pandemi'],
#  ['dukung',
#   'target',
#   'vaksinasi',
#   'indonesia',
#   'kedatangan',
#   'juta',
#   'vaksin',
#   'moderna',
#   'dan',
#   'ribu',
#   'vaksin',
#   'astrazenecca'],
#  ['tahap', 'indonesia', 'datangkan', 'juta', 'dosis', 'vaksin', 'pfizer'],
#  ['tahap',
#   'ke',
#   'dosis',
#   'vaksin',
#   'astrazeneca',
#   'tiba',
#   'di',
#   'tanah',
#   'air'],
#  ['vaksin', 'covid', 'sebabkan', 'mandul'],
#  ['foto',
#   'orang',
#   'alami',
#   'kelumpuhan',
#   'wajah',
#   'setelah',
#   'disuntik',
#   'vaksin',
#   'corona'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['tahap',
#   'verifikasi',
#   'bagi',
#   'wni',
#   'dan',
#   'wna',
#   'yang',
#   'vaksin',
#   'di',
#   'luar',
#   'negeri'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['vaksinasi',
#   'lansia',
#   'sudah',
#   'siap',
#   'perlu',
#   'dukungan',
#   'semua',
#   'pihak',
#   'menyukseskannya'],
#  ['tidak',
#   'perlu',
#   'pilihpilih',
#   'jenis',
#   'vaksin',
#   'covid',
#   'manfaatnya',
#   'sama'],
#  ['vaksin',
#   'tahap',
#   'ke',
#   'tiba',
#   'di',
#   'bandara',
#   'soekarnohatta',
#   'dan',
#   'ahmad',
#   'yani'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['jadwal',
#   'vaksinasi',
#   'massal',
#   'di',
#   'royal',
#   'plaza',
#   'surabaya',
#   'tanggal',
#   'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['menteri',
#   'luar',
#   'negeri',
#   'diplomasi',
#   'vaksin',
#   'terus',
#   'dilanjutkan',
#   'untuk',
#   'mengawal',
#   'vaksinasi',
#   'covid'],
#  ['vaksin', 'covid', 'mengandung', 'microchip', 'magnetik'],
#  ['sambut',
#   'kedatangan',
#   'vaksin',
#   'moderna',
#   'dan',
#   'astrazenecca',
#   'menlu',
#   'mekanisme',
#   'dosesharing',
#   'vaksin',
#   'penting',
#   'agar',
#   'dunia',
#   'dapat',
#   'keluar',
#   'dari',
#   'pandemi'],
#  ['sentra', 'vaksinasi', 'bersama', 'bumn', 'hadir', 'di', 'jawa', 'tengah'],
#  ['indonesia', 'peringkat', 'ke', 'dunia', 'vaksinasi', 'terbanyak'],
#  ['kedatangan', 'vaksin', 'covid', 'tahap', 'keempat', 'di', 'indonesia'],
#  ['awas',
#   'hoaks',
#   'seorang',
#   'pria',
#   'tewas',
#   'karena',
#   'makan',
#   'durian',
#   'setelah',
#   'divaksin'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['hoaks',
#   'danramil',
#   'kebomas',
#   'di',
#   'gresik',
#   'meninggal',
#   'akibat',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['aman', 'dan', 'efektif', 'adalah', 'prinsip', 'utama', 'vaksin', 'covid'],
#  ['tahap',
#   'ke',
#   'juta',
#   'vaksin',
#   'jadi',
#   'dari',
#   'sinovac',
#   'tiba',
#   'kembali',
#   'di',
#   'indonesia',
#   'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['awas',
#   'hoaks',
#   'setelah',
#   'divaksin',
#   'bisa',
#   'sebabkan',
#   'hasil',
#   'tes',
#   'covid',
#   'positif'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['korea',
#   'selatan',
#   'kelabakan',
#   'lihat',
#   'warganya',
#   'meninggal',
#   'satu',
#   'persatu',
#   'usai',
#   'disuntik',
#   'vaksin'],
#  ['masjid',
#   'siap',
#   'jadi',
#   'sentra',
#   'vaksinasi',
#   'dan',
#   'prioritaskan',
#   'lansia'],
#  ['bahaya',
#   'donor',
#   'darah',
#   'dari',
#   'orang',
#   'yang',
#   'sudah',
#   'divaksin',
#   'covid'],
#  ['video',
#   'setelah',
#   'disuntik',
#   'vaksin',
#   'pingsan',
#   'tak',
#   'sadarkan',
#   'diri'],
#  ['informasi',
#   'vaksin',
#   'dosis',
#   'dan',
#   'agustus',
#   'di',
#   'rsal',
#   'dr',
#   'ramelan',
#   'surabaya'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['vaksinasi',
#   'covid',
#   'tahap',
#   'dimulai',
#   'untuk',
#   'masyarakat',
#   'rentan',
#   'di',
#   'jakarta'],
#  ['rekomendasi',
#   'hindari',
#   'tekanan',
#   'darah',
#   'tinggi',
#   'sebelum',
#   'vaksinasi',
#   'covid'],
#  ['tahap',
#   'ke',
#   'tiba',
#   'dosis',
#   'vaksin',
#   'pfizer',
#   'vaksinasi',
#   'lansia',
#   'dan',
#   'remaja',
#   'ditingkatkan',
#   'september'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['vaksinasi', 'siap', 'divaksin', 'saat', 'vaksin', 'siap'],
#  ['hasil',
#   'uji',
#   'badan',
#   'pom',
#   'vaksin',
#   'covid',
#   'astrazeneca',
#   'nomor',
#   'batch',
#   'ctmav',
#   'penuhi',
#   'syarat',
#   'mutu',
#   'sehingga',
#   'aman',
#   'digunakan'],
#  ['covid',
#   'bermutasi',
#   'menjadi',
#   'virus',
#   'baru',
#   'yang',
#   'lebih',
#   'berbahaya',
#   'dan',
#   'vaksinasi',
#   'timbulkan',
#   'virus',
#   'lain',
#   'dari',
#   'covid'],
#  ['pemda',
#   'diminta',
#   'percepat',
#   'vaksinasi',
#   'untuk',
#   'pendidik',
#   'dan',
#   'tenaga',
#   'pendidik',
#   'upaya',
#   'dukung',
#   'pembelajaran',
#   'tatap',
#   'muka',
#   'ptm',
#   'terbatas'],
#  ['setelah',
#   'di',
#   'vaksin',
#   'maka',
#   'kasus',
#   'hiv',
#   'dan',
#   'kanker',
#   'akan',
#   'meledak'],
#  ['awas',
#   'misinformasi',
#   'nama',
#   'di',
#   'surat',
#   'vaksinasi',
#   'harus',
#   'sesuai',
#   'dengan',
#   'paspor'],
#  ['dosis', 'vaksin', 'dari', 'covax', 'tiba', 'di', 'indonesia', 'april'],
#  ['awas',
#   'hoaks',
#   'uni',
#   'eropa',
#   'hentikan',
#   'vaksin',
#   'covid',
#   'mulai',
#   'oktober'],
#  ['pemerintah', 'kawal', 'kesiapan', 'sarana', 'vaksin', 'covid'],
#  ['kapan',
#   'waktu',
#   'terbaik',
#   'menerima',
#   'vaksin',
#   'covid',
#   'dosis',
#   'kedua',
#   'beda',
#   'vaksin',
#   'beda',
#   'jarak',
#   'waktunya'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['juta', 'vaksin', 'sinovac', 'tiba', 'di', 'indonesia'],
#  ['awas',
#   'hoaks',
#   'video',
#   'bayi',
#   'terlahir',
#   'cacat',
#   'akibat',
#   'vaksin',
#   'covid',
#   'di',
#   'india'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['pemberian',
#   'vaksin',
#   'astrazeneca',
#   'non',
#   'batch',
#   'ctmav',
#   'tetap',
#   'dilanjutkan'],
#  ['awas',
#   'hoaks',
#   'tidak',
#   'boleh',
#   'konsumsi',
#   'makanan',
#   'dan',
#   'minuman',
#   'yang',
#   'mengandung',
#   'alkohol',
#   'dan',
#   'soda',
#   'setelah',
#   'vaksin',
#   'covid'],
#  ['vaksin',
#   'covid',
#   'lindungi',
#   'kita',
#   'dari',
#   'covid',
#   'termasuk',
#   'dari',
#   'virus',
#   'varian',
#   'baru'],
#  ['tahap',
#   'ke',
#   'ribu',
#   'dosis',
#   'vaksin',
#   'sinopharm',
#   'tiba',
#   'di',
#   'tanah',
#   'air',
#   'agustus'],
#  ['ketua',
#   'komite',
#   'kpcpen',
#   'airlangga',
#   'hartarto',
#   'juta',
#   'dosis',
#   'vaksin',
#   'tiba',
#   'akhir',
#   'tahun'],
#  ['masyarakat',
#   'disarankan',
#   'tidak',
#   'menunda',
#   'vaksinasi',
#   'karena',
#   'kekhawatiran',
#   'varian',
#   'baru',
#   'covid'],
#  ['dosis', 'vaksin', 'covid', 'ini', 'tujuannya'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['kenali',
#   'gejala',
#   'long',
#   'covid',
#   'dan',
#   'manfaat',
#   'vaksin',
#   'jika',
#   'sampai',
#   'terkena',
#   'covid'],
#  ['tahap', 'ke', 'kedatangan', 'dosis', 'vaksin', 'astrazeneca', 'agustus'],
#  ['kemenkesunicef',
#   'tandatangani',
#   'kerja',
#   'sama',
#   'pengadaan',
#   'vaksin',
#   'dan',
#   'obat',
#   'yang',
#   'terjangkau'],
#  ['percepat', 'vaksinasi', 'pendidik', 'dan', 'tenaga', 'kependidikan'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['cakupan',
#   'vaksinasi',
#   'dosis',
#   'pertama',
#   'hampir',
#   'untuk',
#   'penyandang',
#   'disabilitas',
#   'di',
#   'jawabali'],
#  ['pemerintah',
#   'mulai',
#   'suntikkan',
#   'booster',
#   'vaksin',
#   'covid',
#   'moderna',
#   'untuk',
#   'tenaga',
#   'kesehatan'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['lebih',
#   'juta',
#   'rakyat',
#   'indonesia',
#   'telah',
#   'divaksin',
#   'percepatan',
#   'terus',
#   'dilakukan'],
#  ['indonesia',
#   'terima',
#   'juta',
#   'vaksin',
#   'astrazeneca',
#   'dari',
#   'perjanjian',
#   'bilateral'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['tahap',
#   'ke',
#   'indonesia',
#   'terima',
#   'dosis',
#   'vaksin',
#   'covid',
#   'astrazeneca',
#   'agustus'],
#  ['kadin',
#   'perusahaan',
#   'terdaftar',
#   'untuk',
#   'vaksinasi',
#   'gotong',
#   'royong'],
#  ['vaksin', 'bermanfaat', 'besar', 'lindungi', 'masyarakat'],
#  ['sistem', 'distribusi', 'vaksin', 'dikelola', 'secara', 'terintegrasi'],
#  ['satgas', 'covid', 'chip', 'dalam', 'vaksin', 'adalah', 'berita', 'bohong'],
#  ['kedatangan',
#   'vaksin',
#   'pfizer',
#   'langsung',
#   'didistribusikan',
#   'ke',
#   'delapan',
#   'provinsi'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['juta', 'dosis', 'vaksin', 'astrazeneca', 'tiba', 'di', 'tanah', 'air'],
#  ['strategi', 'pemerintah', 'dalam', 'vaksinasi', 'untuk', 'pekerja', 'seni'],
#  ['indonesia', 'siap', 'uji', 'klinis', 'kandidat', 'vaksin', 'covid'],
#  ['sertifikat',
#   'vaksin',
#   'menjadi',
#   'syarat',
#   'pengisian',
#   'bbm',
#   'di',
#   'spbu',
#   'wilayah',
#   'trumon',
#   'raya',
#   'aceh',
#   'selatan'],
#  ['video',
#   'eric',
#   'tohir',
#   'sangat',
#   'terbuka',
#   'menjelaskan',
#   'tentang',
#   'chip',
#   'yang',
#   'ada',
#   'dalam',
#   'vaksin',
#   'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['vaksin',
#   'covid',
#   'moderna',
#   'hanya',
#   'untuk',
#   'booster',
#   'nakes',
#   'dan',
#   'publik',
#   'yang',
#   'belum',
#   'pernah',
#   'menerima',
#   'vaksin',
#   'covid'],
#  ['lebih',
#   'dari',
#   'miliar',
#   'dosis',
#   'vaksin',
#   'covid',
#   'astrazeneca',
#   'telah',
#   'diterima',
#   'masyarakat',
#   'dunia',
#   'who',
#   'vaksin',
#   'ini',
#   'aman'],
#  ['telapak',
#   'kaki',
#   'relawan',
#   'melepuh',
#   'efek',
#   'samping',
#   'suntik',
#   'vaksin',
#   'covid'],
#  ['vaksinasi', 'gotong', 'royong', 'bayar', 'atau', 'gratis'],
#  ['pesan', 'berantai', 'video', 'potensi', 'bahaya', 'vaksin', 'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['kandidat',
#   'vaksin',
#   'covid',
#   'di',
#   'indonesia',
#   'mandiri',
#   'dan',
#   'kolaboratif'],
#  ['semua',
#   'vaksin',
#   'sama',
#   'baiknya',
#   'masyarakat',
#   'diminta',
#   'tidak',
#   'menundanunda',
#   'vaksinasi'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['video',
#   'di',
#   'probolinggo',
#   'juli',
#   'meninggal',
#   'bersama',
#   'orang',
#   'serumah',
#   'setelah',
#   'di',
#   'vaksin'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['program',
#   'vaksinasi',
#   'massal',
#   'harus',
#   'mempertimbangkan',
#   'ketersediaan',
#   'tenaga',
#   'vaksinator'],
#  ['kesuksesan',
#   'program',
#   'vaksinasi',
#   'akan',
#   'dorong',
#   'pemulihan',
#   'ekonomi'],
#  ['panggilan', 'telepon', 'informasi', 'seputar', 'vaksinasi'],
#  ['sebanyak',
#   'ribu',
#   'vaksin',
#   'astrazeneca',
#   'hibah',
#   'pemerintah',
#   'australia',
#   'tiba',
#   'di',
#   'tanah',
#   'air'],
#  ['vaksin',
#   'gotong',
#   'royong',
#   'bentuk',
#   'tanggung',
#   'jawab',
#   'pengusaha',
#   'pada',
#   'karyawan'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['jokowi',
#   'kejang',
#   'dan',
#   'meninggal',
#   'dunia',
#   'setelah',
#   'disuntik',
#   'vaksin'],
#  ['idi', 'optimis', 'vaksinasi', 'akan', 'hentikan', 'penularan', 'covid'],
#  ['jokowi', 'menggunakan', 'vaksin', 'buatan', 'eropa'],
#  ['awas',
#   'hoaks',
#   'dokter',
#   'wafat',
#   'karena',
#   'covid',
#   'dalam',
#   'waktu',
#   'jam',
#   'setelah',
#   'disuntik',
#   'vaksin'],
#  ['singapura',
#   'hentikan',
#   'vaksinasi',
#   'setelah',
#   'orang',
#   'meninggal',
#   'di',
#   'negaranya'],
#  ['dari',
#   'cek',
#   'lokasi',
#   'vaksinasi',
#   'hingga',
#   'periksa',
#   'hoaks',
#   'semua',
#   'ada',
#   'di',
#   'httpssidinfovaksin'],
#  ['pecah',
#   'rekor',
#   'vaksinasi',
#   'covid',
#   'tembus',
#   'angka',
#   'juta',
#   'per',
#   'hari'],
#  ['pusat',
#   'vaksinasi',
#   'di',
#   'daerah',
#   'melalui',
#   'kolaborasi',
#   'semua',
#   'pihak'],
#  ['delapan',
#   'juta',
#   'dosis',
#   'vaksin',
#   'tahap',
#   'tiba',
#   'vaksinasi',
#   'diharapkan',
#   'sesuai',
#   'target'],
#  ['vaksin',
#   'covid',
#   'produksi',
#   'pfizerbiontech',
#   'bisa',
#   'diberikan',
#   'untuk',
#   'usia',
#   'tahun',
#   'ke',
#   'atas'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['kumham',
#   'hapus',
#   'sanksi',
#   'pidana',
#   'setelah',
#   'anak',
#   'buah',
#   'megawati',
#   'tolak',
#   'vaksin'],
#  ['lima',
#   'juta',
#   'vaksin',
#   'tiba',
#   'di',
#   'tanah',
#   'air',
#   'indonesia',
#   'telah',
#   'amankan',
#   'lebih',
#   'juta',
#   'dosis',
#   'vaksin'],
#  ['para',
#   'pemangku',
#   'kepentingan',
#   'vaksin',
#   'covid',
#   'diminta',
#   'patuhi',
#   'ketentuan',
#   'perpres',
#   'no',
#   'tahun'],
#  ['kedatangan',
#   'tahap',
#   'ke',
#   'bio',
#   'farma',
#   'pastikan',
#   'vaksin',
#   'segera',
#   'didistribusikan',
#   'ke',
#   'seluruh',
#   'provinsi'],
#  ['awak', 'media', 'mulai', 'menerima', 'vaksin', 'covid'],
#  ['vaksin',
#   'covid',
#   'berbasis',
#   'mrna',
#   'dapat',
#   'mengubah',
#   'dna',
#   'manusia'],
#  ['vaksin',
#   'sinovac',
#   'teruji',
#   'minim',
#   'efek',
#   'samping',
#   'berkhasiat',
#   'dan',
#   'halal'],
#  ['pemerintah', 'upayakan', 'pemerataan', 'penerima', 'vaksin', 'nasional'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['vaksin', 'meningkatkan', 'imunitas', 'tubuh'],
#  ['prioritaskan', 'vaksinasi', 'untuk', 'lansia'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['video',
#   'seorang',
#   'kakek',
#   'ditahan',
#   'karena',
#   'tidak',
#   'memakai',
#   'masker',
#   'setelah',
#   'vaksinasi'],
#  ['protokol',
#   'kesehatan',
#   'yang',
#   'diperkuat',
#   'vaksin',
#   'adalah',
#   'upaya',
#   'pencegahan',
#   'terbaik'],
#  ['vaksin',
#   'covid',
#   'belum',
#   'ditemukan',
#   'lindungi',
#   'diri',
#   'dengan',
#   'lakukan',
#   'protokol',
#   'kesehatan'],
#  ['tambahan',
#   'bulk',
#   'vaksin',
#   'menjamin',
#   'kelancaran',
#   'program',
#   'vaksinasi',
#   'di',
#   'seluruh',
#   'daerah'],
#  ['awas',
#   'hoaks',
#   'seorang',
#   'pria',
#   'tewas',
#   'karena',
#   'makan',
#   'durian',
#   'setelah',
#   'divaksin'],
#  ['badan',
#   'pom',
#   'terus',
#   'kawal',
#   'keamanan',
#   'khasiat',
#   'dan',
#   'mutu',
#   'vaksin',
#   'covid'],
#  ['apakah', 'vaksin', 'covid', 'hanya', 'untuk', 'peserta', 'bpjs'],
#  ['video',
#   'perawat',
#   'pingsan',
#   'setelah',
#   'mendapat',
#   'vaksin',
#   'covid',
#   'potensi',
#   'genosida',
#   'massal'],
#  ['kriteria',
#   'penetapan',
#   'emergency',
#   'use',
#   'authorization',
#   'eua',
#   'untuk',
#   'vaksin',
#   'covid'],
#  ['indonesia',
#   'terima',
#   'juta',
#   'vaksin',
#   'moderna',
#   'dan',
#   'juta',
#   'vaksin',
#   'astrazeneca',
#   'juli'],
#  ['minum',
#   'air',
#   'kelapa',
#   'sebagai',
#   'penangkal',
#   'racun',
#   'usai',
#   'divaksin'],
#  ['penanganan',
#   'kipi',
#   'untuk',
#   'program',
#   'vaksinasi',
#   'nasional',
#   'ditanggung',
#   'pemerintah'],
#  ['menerima',
#   'vaksin',
#   'dapat',
#   'menekan',
#   'peluang',
#   'lahirnya',
#   'varian',
#   'baru',
#   'covid'],
#  ['bulan',
#   'pandemi',
#   'pemerintah',
#   'terus',
#   'kerja',
#   'keras',
#   'dan',
#   'upayakan',
#   'pengadaan',
#   'vaksin',
#   'covid'],
#  ['awas', 'hoaks', 'tukul', 'sakit', 'pendarahan', 'otak', 'karena', 'vaksin'],
#  ['orang',
#   'di',
#   'korea',
#   'selatan',
#   'meninggal',
#   'setelah',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['tahap', 'indonesia', 'datangkan', 'juta', 'dosis', 'vaksin', 'sinovac'],
#  ['vaksinasi',
#   'tahap',
#   'kedua',
#   'bagi',
#   'petugas',
#   'pelayanan',
#   'publik',
#   'siap',
#   'dilaksanakan'],
#  ['awas',
#   'hoaks',
#   'harga',
#   'vaksin',
#   'di',
#   'indonesia',
#   'lebih',
#   'mahal',
#   'daripada',
#   'di',
#   'brazil'],
#  ['kenapa',
#   'semua',
#   'nya',
#   'meninggal',
#   'dengan',
#   'ciri',
#   'ciri',
#   'penyebab',
#   'yg',
#   'sama',
#   'seperti',
#   'korban',
#   'vaksin',
#   'covid',
#   'lain',
#   'di',
#   'luar',
#   'negeri'],
#  ['verifikasi',
#   'vaksinasi',
#   'pedulilindungi',
#   'memudahkan',
#   'wna',
#   'dan',
#   'wni',
#   'mengakses',
#   'fasilitas',
#   'publik'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['foto', 'dokter', 'menyatakan', 'covid', 'disebarkan', 'melalui', 'vaksin'],
#  ['pembuatan',
#   'group',
#   'whatsapp',
#   'info',
#   'wilayah',
#   'penularan',
#   'covid',
#   'dan',
#   'pembagian',
#   'vaksin'],
#  ['bagaimana', 'kerja', 'vaksin'],
#  ['optimalisasi',
#   'upaya',
#   'pemenuhan',
#   'ketersediaan',
#   'dan',
#   'distribusi',
#   'vaksin',
#   'covid'],
#  ['juta', 'vaksin', 'bulk', 'covid', 'kembali', 'datang', 'ke', 'indonesia'],
#  ['perbedaan', 'kemasan', 'vaksin', 'covid'],
#  ['kelompok',
#   'lansia',
#   'komorbid',
#   'penyintas',
#   'covid',
#   'dan',
#   'ibu',
#   'menyusui',
#   'bisa',
#   'divaksinasi',
#   'ini',
#   'syaratnya'],
#  ['tentang',
#   'penjelasan',
#   'pemerintah',
#   'sehubungan',
#   'dengan',
#   'penyebaran',
#   'informasi',
#   'sertifikat',
#   'vaksinasi',
#   'covid',
#   'bapak',
#   'presiden',
#   'joko',
#   'widodo'],
#  ['awas',
#   'hoaks',
#   'vaksin',
#   'covid',
#   'beresiko',
#   'tinggi',
#   'bagi',
#   'perempuan',
#   'yang',
#   'sedang',
#   'menstruasi'],
#  ['menko',
#   'pmk',
#   'tekankan',
#   'vaksinasi',
#   'memprioritaskan',
#   'garda',
#   'depan'],
#  ['buah',
#   'diplomasi',
#   'vaksin',
#   'indonesia',
#   'terima',
#   'kedatangan',
#   'pertama',
#   'vaksin',
#   'dari',
#   'covax',
#   'sebanyak',
#   'juta',
#   'dosis'],
#  ['sebanyak',
#   'juta',
#   'vaksin',
#   'coronavac',
#   'lulus',
#   'uji',
#   'sertifikasi',
#   'lot',
#   'release'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['mayoritas',
#   'masyarakat',
#   'indonesia',
#   'bersedia',
#   'menerima',
#   'vaksin',
#   'covid'],
#  ['cari',
#   'tahu',
#   'informasi',
#   'seputar',
#   'kipi',
#   'dampak',
#   'vaksin',
#   'covid',
#   'di',
#   'kipicovidgoid'],
#  ['presiden',
#   'akan',
#   'tinjau',
#   'fasilitas',
#   'produksi',
#   'dan',
#   'pelaksanaan',
#   'uji',
#   'klinis',
#   'vaksin',
#   'covid'],
#  ['vaksin',
#   'astrazeneca',
#   'kantongi',
#   'izin',
#   'penggunaan',
#   'dari',
#   'mui',
#   'dan',
#   'bpom'],
#  ['soal',
#   'vaksinasi',
#   'covid',
#   'indonesia',
#   'bertengger',
#   'di',
#   'peringkat',
#   'dunia'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['foto', 'munarman', 'udah', 'divaksin'],
#  ['inilah', 'juru', 'bicara', 'vaksinasi', 'covid'],
#  ['korban', 'vaksin', 'lagi', 'kini', 'anggota', 'brimob', 'di', 'maluku'],
#  ['awas',
#   'hoaks',
#   'video',
#   'jarum',
#   'suntik',
#   'menghilang',
#   'saat',
#   'proses',
#   'vaksinasi'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['yuk', 'cek', 'fakta', 'seputar', 'mitos', 'vaksin'],
#  ['seluruh',
#   'hewan',
#   'percobaan',
#   'vaksin',
#   'covid',
#   'terbukti',
#   'mati',
#   'karena',
#   'suntik',
#   'vaksin'],
#  ['vaksin', 'gotong', 'royong', 'upaya', 'perlindungan', 'bagi', 'pekerja'],
#  ['untuk',
#   'dukung',
#   'kesiapan',
#   'ptm',
#   'terbatas',
#   'vaksinasi',
#   'untuk',
#   'pelajar',
#   'dipercepat'],
#  ['awas',
#   'hoaks',
#   'ribuan',
#   'orang',
#   'di',
#   'indonesia',
#   'meninggal',
#   'dunia',
#   'setelah',
#   'vaksin',
#   'covid'],
#  ['kedatangan',
#   'vaksin',
#   'covid',
#   'ke',
#   'lima',
#   'puluh',
#   'di',
#   'tanah',
#   'air'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['cara', 'ampuh', 'lawan', 'covid', 'm', 't', 'vaksin'],
#  ['tanggal',
#   'pembuatan',
#   'vaksin',
#   'adalah',
#   'setahun',
#   'sebelum',
#   'covid',
#   'melanda'],
#  ['jokowi',
#   'hari',
#   'ini',
#   'tolak',
#   'di',
#   'suntik',
#   'vaksin',
#   'covid',
#   'duluan'],
#  ['kedatangan',
#   'vaksin',
#   'covid',
#   'tahap',
#   'ke',
#   'indonesia',
#   'terima',
#   'dukungan',
#   'vaksin',
#   'kedua',
#   'dari',
#   'pemerintah',
#   'inggris'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['jangan', 'terlena', 'ayo', 'pakai', 'masker', 'ayo', 'cepat', 'vaksin'],
#  ['cara', 'vaksin', 'picu', 'kekebalan', 'tubuh'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['belum',
#   'ditemukan',
#   'kejadian',
#   'ikutan',
#   'pasca',
#   'imunisasi',
#   'kipi',
#   'berat',
#   'pada',
#   'pelaksanaan',
#   'vaksinasi',
#   'covid',
#   'bagi',
#   'lansia'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['awas',
#   'hoaks',
#   'negara',
#   'melarang',
#   'penyebaran',
#   'vaksin',
#   'astrazeneca'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['ketua',
#   'tim',
#   'peneliti',
#   'pfizer',
#   'vaksin',
#   'covid',
#   'dapat',
#   'menyebabkan',
#   'kemandulan',
#   'bagi',
#   'perempuan'],
#  ['tahap',
#   'ke',
#   'indonesia',
#   'terima',
#   'juta',
#   'dosis',
#   'bahan',
#   'baku',
#   'vaksin',
#   'sinovac'],
#  ['awas',
#   'hoaks',
#   'setelah',
#   'divaksin',
#   'maka',
#   'kasus',
#   'hiv',
#   'dan',
#   'kanker',
#   'akan',
#   'meledak'],
#  ['dulu',
#   'diantar',
#   'untuk',
#   'vaksin',
#   'sekarang',
#   'mengantar',
#   'untuk',
#   'vaksin'],
#  ['calon', 'jemaah', 'haji', 'lansia', 'terima', 'vaksin', 'covid'],
#  ['protokol',
#   'kesehatan',
#   'dan',
#   'vaksin',
#   'saling',
#   'melengkapi',
#   'guna',
#   'akhiri',
#   'covid'],
#  ['fakta',
#   'dan',
#   'data',
#   'tunjukkan',
#   'vaksinasi',
#   'covid',
#   'kurangi',
#   'risiko',
#   'sakit',
#   'berat',
#   'dan',
#   'turunkan',
#   'tingkat',
#   'kematian'],
#  ['dapat',
#   'informasi',
#   'vaksin',
#   'covid',
#   'yang',
#   'bikin',
#   'degdegan',
#   'cek',
#   'hoaks',
#   'atau',
#   'bukan'],
#  ['skema', 'pelayanan', 'vaksinasi', 'covid', 'tahap', 'kedua'],
#  ['tahap',
#   'ke',
#   'juta',
#   'dosis',
#   'bahan',
#   'baku',
#   'vaksin',
#   'covid',
#   'tiba',
#   'di',
#   'tanah',
#   'air'],
#  ['tambahan', 'dosis', 'vaksin', 'astrazeneca', 'tiba', 'di', 'tanah', 'air'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['belum',
#   'ditemukan',
#   'reaksi',
#   'anafilaktik',
#   'dalam',
#   'pelaksanaan',
#   'vaksinasi',
#   'covid'],
#  ['indonesia',
#   'tambah',
#   'pasokan',
#   'satu',
#   'juta',
#   'dosis',
#   'vaksin',
#   'sinopharm'],
#  ['vaksinasi',
#   'tembus',
#   'juta',
#   'dosis',
#   'indonesia',
#   'masuk',
#   'besar',
#   'dunia'],
#  ['tahap', 'ke', 'dosis', 'vaksin', 'pfizer'],
#  ['kedatangan',
#   'vaksin',
#   'sinopharm',
#   'teguhkan',
#   'upaya',
#   'kolaborasi',
#   'dan',
#   'gotong',
#   'royong',
#   'hadapi',
#   'pandemi'],
#  ['balita',
#   'divaksin',
#   'upaya',
#   'menuju',
#   'pemusnahan',
#   'massal',
#   'umat',
#   'islam'],
#  ['sakit', 'mendadak', 'oleh', 'vaksin'],
#  ['inilah', 'tahapan', 'vaksinasi', 'covid'],
#  ['tahap', 'ke', 'indonesia', 'kedatangan', 'juta', 'vaksin', 'sinovac'],
#  ['foto',
#   'syuting',
#   'film',
#   'horor',
#   'agar',
#   'masyarakat',
#   'indonesia',
#   'mau',
#   'divaksin'],
#  ['masyarakat',
#   'jangan',
#   'terlena',
#   'euforia',
#   'ayo',
#   'pakai',
#   'masker',
#   'dan',
#   'cepat',
#   'vaksinasi'],
#  ['cek',
#   'data',
#   'testing',
#   'tracing',
#   'tingkat',
#   'kabupatenkota',
#   'di',
#   'httpsvaksinkemkesgoidsckab'],
#  ['obat',
#   'covid',
#   'dexamethasone',
#   'lebih',
#   'murah',
#   'dari',
#   'harga',
#   'vaksin',
#   'covid'],
#  ['reaksi',
#   'pascavaksinasi',
#   'covid',
#   'kebanyakan',
#   'hanya',
#   'pegal',
#   'lapar',
#   'dan',
#   'ngantuk'],
#  ['kapan', 'bisa', 'vaksin', 'dosis', 'kedua'],
#  ['vaksin',
#   'dan',
#   'tenaga',
#   'kesehatan',
#   'cukup',
#   'tak',
#   'ada',
#   'alasan',
#   'tidak',
#   'vaksinasi',
#   'di',
#   'empat',
#   'klaster',
#   'pon',
# ...
#   'hoaks',
#   'maskapai',
#   'penerbangan',
#   'internasional',
#   'melarang',
#   'penumpang',
#   'yang',
#   'sudah',
#   'divaksinasi',
#   'untuk',
#   'melakukan',
#   'perjalanan',
#   'penerbangan'],
#  ['sukses',
#   'vaksinasi',
#   'tahap',
#   'kedua',
#   'perlu',
#   'dibarengi',
#   'kepatuhan',
#   'prokes'],
#  ['bukan',
#   'karena',
#   'vaksin',
#   'covid',
#   'respon',
#   'vagal',
#   'sebabkan',
#   'seorang',
#   'perawat',
#   'pingsan'],
#  ['china',
#   'akui',
#   'dokter',
#   'palestina',
#   'penemu',
#   'vaksin',
#   'corona',
#   'yang',
#   'terbukti',
#   'ampuh',
#   'persen'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['pemerintah',
#   'upayakan',
#   'lansia',
#   'mudah',
#   'menjangkau',
#   'lokasi',
#   'vaksinasi'],
#  ['awas',
#   'disinformasi',
#   'vaksin',
#   'covid',
#   'sinovac',
#   'ilegal',
#   'karena',
#   'tak',
#   'bersertifikasi',
#   'who'],
#  ['warga', 'tak', 'punya', 'nik', 'bisa', 'divaksinasi'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['tahap',
#   'ke',
#   'indonesia',
#   'datangkan',
#   'juta',
#   'dosis',
#   'vaksin',
#   'pfizer',
#   'september'],
#  ['fatwa', 'mui', 'vaksinasi', 'injeksi', 'tak', 'membatalkan', 'puasa'],
#  ['sudah', 'divaksin', 'kok', 'tetap', 'harus'],
#  ['hoaks',
#   'danramil',
#   'kebomas',
#   'di',
#   'gresik',
#   'meninggal',
#   'akibat',
#   'disuntik',
#   'vaksin',
#   'covid'],
#  ['misinformasi',
#   'informasi',
#   'daftar',
#   'harga',
#   'pelayanan',
#   'vaksin',
#   'covid',
#   'rs',
#   'pelni'],
#  ['kedatangan',
#   'vaksin',
#   'tahap',
#   'ke',
#   'indonesia',
#   'dapat',
#   'tambahan',
#   'juta',
#   'dosis',
#   'vaksin',
#   'dari',
#   'covax',
#   'facility'],
#  ['foto', 'suasana', 'demo', 'antivaksin', 'di', 'prancis'],
#  ['vaksin', 'lindungi', 'diri', 'lindungi', 'negeri'],
#  ['sinovac', 'kirimkan', 'vaksin', 'curah', 'apa', 'maksudnya'],
#  ['menteri',
#   'kesehatan',
#   'gandeng',
#   'semua',
#   'elemen',
#   'sukseskan',
#   'program',
#   'vaksinasi'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['jadi',
#   'butuh',
#   'vaksin',
#   'covid',
#   'booster',
#   'atau',
#   'enggak',
#   'ini',
#   'pandangan',
#   'who'],
#  ['indonesia', 'tidak', 'dapat', 'menggugat', 'jika', 'vaksin', 'bermasalah'],
#  ['tahap',
#   'ke',
#   'dosis',
#   'vaksin',
#   'sinovac',
#   'tiba',
#   'di',
#   'indonesia',
#   'september'],
#  ['awas',
#   'hoaks',
#   'penerbangan',
#   'di',
#   'as',
#   'ditutup',
#   'karena',
#   'kru',
#   'dan',
#   'pilot',
#   'menolak',
#   'vaksin'],
#  ['tangkapan',
#   'layar',
#   'video',
#   'cnn',
#   'memberitakan',
#   'rakyat',
#   'akan',
#   'dibunuh',
#   'oleh',
#   'vaksin',
#   'dari',
#   'tiongkok'],
#  ['tidak',
#   'boleh',
#   'mengonsumsi',
#   'makanan',
#   'dan',
#   'minuman',
#   'yang',
#   'mengandung',
#   'alkohol',
#   'dan',
#   'soda',
#   'setelah',
#   'vaksin',
#   'covid'],
#  ['kabar',
#   'dari',
#   'kandidat',
#   'vaksin',
#   'covid',
#   'vaksin',
#   'merah',
#   'putih',
#   'karya',
#   'anak',
#   'bangsa'],
#  ['kedatangan',
#   'vaksin',
#   'tahap',
#   'ke',
#   'pemerintah',
#   'dorong',
#   'vaksinasi',
#   'lansia',
#   'dan',
#   'remaja'],
#  ['apa', 'vaksin', 'covid', 'yang', 'terbaik', 'untuk', 'saya'],
#  ['perkuat',
#   'komitmen',
#   'multilateral',
#   'covax',
#   'facility',
#   'kembali',
#   'kirimkan',
#   'juta',
#   'dosis',
#   'vaksin',
#   'ke',
#   'indonesia'],
#  ['tahap',
#   'ke',
#   'juta',
#   'dosis',
#   'vaksin',
#   'sinovac',
#   'tiba',
#   'di',
#   'tanah',
#   'air'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['vaksin',
#   'covid',
#   'produksi',
#   'sinovac',
#   'habis',
#   'digunakan',
#   'sebelum',
#   'masa',
#   'simpan',
#   'berakhir'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juli'],
#  ['awas', 'hoaks', 'vaksin', 'sinovac', 'mandiri', 'seharga', 'rp', 'ribu'],
#  ['fatwa',
#   'mui',
#   'penggunaan',
#   'vaksin',
#   'covid',
#   'astrazeneca',
#   'pada',
#   'saat',
#   'ini',
#   'dibolehkan',
#   'mubah'],
#  ['bio',
#   'farma',
#   'siapkan',
#   'sistem',
#   'pelacakan',
#   'untuk',
#   'distribusi',
#   'vaksin',
#   'covid'],
#  ['kedatangan', 'tahap', 'juta', 'vaksin', 'covid', 'produksi', 'sinovac'],
#  ['badan',
#   'pom',
#   'terbitkan',
#   'izin',
#   'penggunaan',
#   'darurat',
#   'eua',
#   'untuk',
#   'vaksin',
#   'sinopharm'],
#  ['penerima',
#   'vaksin',
#   'perdana',
#   'meninggal',
#   'dunia',
#   'usai',
#   'disuntik',
#   'vaksin',
#   'pfizer'],
#  ['tangkapan',
#   'layar',
#   'hati',
#   'rakyat',
#   'akan',
#   'dibunuh',
#   'vaksin',
#   'cina',
#   'video',
#   'cnn',
#   'indonesia'],
#  ['vaksin', 'melemahkan', 'kekuatan', 'tni'],
#  ['indonesia',
#   'terima',
#   'kedatangan',
#   'vaksin',
#   'tahap',
#   'ke',
#   'wujud',
#   'upaya',
#   'dan',
#   'komitmen',
#   'pemerintah',
#   'amankan',
#   'stok',
#   'vaksin',
#   'covid'],
#  ['awas',
#   'hoaks',
#   'vaksin',
#   'covid',
#   'dapat',
#   'menyebabkan',
#   'kanker',
#   'serviks'],
#  ['anak', 'muda', 'sayangi', 'lansia', 'temani', 'vaksinasi', 'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['menkominfo', 'segerakan', 'vaksinasi', 'untuk', 'proteksi', 'ibu', 'hamil'],
#  ['tetap', 'm', 'walau', 'vaksin', 'sudah', 'tiba'],
#  ['pelaksanaan',
#   'perdana',
#   'vaksinasi',
#   'covid',
#   'gotong',
#   'royong',
#   'untuk',
#   'pekerja'],
#  ['semua',
#   'merek',
#   'vaksin',
#   'covid',
#   'di',
#   'indonesia',
#   'terbukti',
#   'aman',
#   'dan',
#   'efektif',
#   'termasuk',
#   'lawan',
#   'varian',
#   'delta'],
#  ['ketua',
#   'bpom',
#   'ditekan',
#   'dan',
#   'diancam',
#   'untuk',
#   'keluarkan',
#   'vaksin',
#   'sinovac'],
#  ['cara', 'penuhi', 'kebutuhan', 'vaksin', 'dalam', 'negeri'],
#  ['video',
#   'wawancara',
#   'ceo',
#   'pfizer',
#   'yang',
#   'menolak',
#   'divaksin',
#   'pada',
#   'agustus'],
#  ['kejadian',
#   'ikutan',
#   'pasca',
#   'imunisasi',
#   'vaksin',
#   'astrazeneca',
#   'termasuk',
#   'ringan'],
#  ['bio',
#   'farma',
#   'distribusikan',
#   'vaksin',
#   'covid',
#   'ke',
#   'seluruh',
#   'indonesia'],
#  ['awas',
#   'misinformasi',
#   'nama',
#   'di',
#   'surat',
#   'vaksinasi',
#   'harus',
#   'sesuai',
#   'dengan',
#   'paspor'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['konsorsium',
#   'riset',
#   'dan',
#   'inovasi',
#   'covid',
#   'kemenristekbrin',
#   'fokus',
#   'berkolaborasi',
#   'bangun',
#   'kemandirian',
#   'vaksin',
#   'nasional'],
#  ['data',
#   'berbagai',
#   'negara',
#   'tunjukkan',
#   'vaksinasi',
#   'covid',
#   'dosis',
#   'efektif',
#   'cegah',
#   'rawat',
#   'inap',
#   'dan',
#   'kematian'],
#  ['bagaimana', 'cara', 'kerja', 'vaksin'],
#  ['bpom',
#   'terbitkan',
#   'izin',
#   'penggunaan',
#   'darurat',
#   'untuk',
#   'vaksin',
#   'zifivax'],
#  ['awas',
#   'hoaks',
#   'video',
#   'bayi',
#   'terlahir',
#   'cacat',
#   'akibat',
#   'vaksin',
#   'covid',
#   'di',
#   'india'],
#  ['syaratsyarat', 'ibu', 'hamil', 'bisa', 'vaksin'],
#  ['vaksin', 'merah', 'putih', 'masuk', 'program', 'vaksinasi', 'pemerintah'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['vaksin', 'tahap', 'didistribusikan', 'ke', 'provinsi'],
#  ['hoaks', 'vaksin', 'covid', 'perlambat', 'cakupan', 'kekebalan', 'kelompok'],
#  ['kedatangan',
#   'tahap',
#   'ke',
#   'dosis',
#   'vaksin',
#   'sinopharm',
#   'tiba',
#   'di',
#   'indonesia',
#   'juli'],
#  ['vaksin', 'perlu', 'didukung', 'kepatuhan', 'masyarakat', 'menerapkan', 'm'],
#  ['dubes',
#   'ri',
#   'untuk',
#   'uni',
#   'emirat',
#   'arab',
#   'dengan',
#   'vaksin',
#   'insya',
#   'allah',
#   'kita',
#   'akan',
#   'sehat'],
#  ['vaksinasi',
#   'covid',
#   'bentuk',
#   'perlindungan',
#   'kepada',
#   'lansia',
#   'dari',
#   'risiko',
#   'kesakitan',
#   'dan',
#   'kematian'],
#  ['kedatangan',
#   'tahap',
#   'ke',
#   'indonesia',
#   'terima',
#   'dosis',
#   'vaksin',
#   'covid',
#   'astrazeneca',
#   'juli'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['judul',
#   'berita',
#   'itv',
#   'tentang',
#   'seorang',
#   'pria',
#   'bersedia',
#   'divaksin',
#   'setelah',
#   'membuat',
#   'tiga',
#   'orang',
#   'temannya',
#   'meninggal',
#   'karena',
#   'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['selama',
#   'hari',
#   'ribu',
#   'lebih',
#   'warga',
#   'sudah',
#   'divaksin',
#   'di',
#   'sentra',
#   'vaksinasi',
#   'bersama',
#   'bumn'],
#  ['vaksinasi',
#   'dan',
#   'protokol',
#   'kesehatan',
#   'sangat',
#   'menentukan',
#   'dalam',
#   'kendalikan',
#   'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'april'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['pemerintah',
#   'tunda',
#   'distribusi',
#   'vaksin',
#   'covid',
#   'astrazeneca',
#   'kedepankan',
#   'asas',
#   'kehatihatian'],
#  ['vaksinasi', 'covid', 'capai', 'juta', 'dosis', 'per', 'april'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['foto',
#   'efek',
#   'samping',
#   'yang',
#   'dialami',
#   'setelah',
#   'vaksinasi',
#   'moderna',
#   'covid'],
#  ['badan',
#   'pom',
#   'kawal',
#   'aspek',
#   'mutu',
#   'keamanan',
#   'dan',
#   'khasiat',
#   'vaksin',
#   'covid'],
#  ['ketentuan',
#   'baru',
#   'mau',
#   'buat',
#   'ktp',
#   'harus',
#   'punya',
#   'sertifikat',
#   'vaksin'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['dosis',
#   'vaksin',
#   'sinopharm',
#   'kembali',
#   'datang',
#   'bentuk',
#   'semangat',
#   'kolaborasi',
#   'dan',
#   'vaksin',
#   'gotong',
#   'royong'],
#  ['masyarakat', 'tetap', 'disiplin', 'm', 'setelah', 'vaksin', 'tiba'],
#  ['pemerintah', 'percepat', 'vaksinasi', 'kelompok', 'disabilitas'],
#  ['pemerintah', 'pastikan', 'transparansi', 'pengelolaan', 'stok', 'vaksin'],
#  ['vaksin', 'ada', 'kandungan', 'zat', 'berbahaya'],
#  ['vaksinasi',
#   'untuk',
#   'pendidik',
#   'dan',
#   'tenaga',
#   'kependidikan',
#   'beri',
#   'harapan',
#   'baru',
#   'bagi',
#   'dunia',
#   'pendidikan'],
#  ['pemerintah',
#   'telah',
#   'siapkan',
#   'sistem',
#   'satu',
#   'data',
#   'vaksinasi',
#   'covid'],
#  ['sudah',
#   'mendapatkan',
#   'vaksinasi',
#   'covid',
#   'protokol',
#   'kesehatan',
#   'jangan',
#   'kendor'],
#  ['tahap',
#   'ke',
#   'dosis',
#   'vaksin',
#   'jadi',
#   'merek',
#   'astrazeneca',
#   'tiba',
#   'di',
#   'indonesia',
#   'agustus'],
#  ['muhammadiyah',
#   'larang',
#   'masyarakat',
#   'dengan',
#   'ktp',
#   'nonislam',
#   'ikut',
#   'vaksin'],
#  ['awas',
#   'hoaks',
#   'vaksin',
#   'covid',
#   'beresiko',
#   'tinggi',
#   'bagi',
#   'perempuan',
#   'yang',
#   'sedang',
#   'menstruasi'],
#  ['lebih',
#   'dari',
#   'pekerja',
#   'seni',
#   'dan',
#   'kreatif',
#   'mendapat',
#   'vaksinasi',
#   'covid'],
#  ['vaksinasi', 'sukses', 'jika', 'didukung', 'm'],
#  ['penampakan', 'protes', 'wajib', 'vaksin', 'di', 'melbourne', 'tahun'],
#  ['vaksin',
#   'covid',
#   'dapat',
#   'diberikan',
#   'sebulan',
#   'setelah',
#   'penyintas',
#   'sembuh'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['lebih',
#   'dari',
#   'juta',
#   'orang',
#   'sudah',
#   'divaksinasi',
#   'covid',
#   'dosis',
#   'pertama',
#   'per',
#   'agustus'],
#  ['badan', 'pom', 'terbitkan', 'eua', 'vaksin', 'covid', 'pfizer'],
#  ['video', 'rusia', 'jadi', 'pemenang', 'pembuatan', 'vaksin', 'c'],
#  ['vaksinasi',
#   'lengkap',
#   'dibarengi',
#   'disiplin',
#   'prokes',
#   'menjadi',
#   'upaya',
#   'penting',
#   'hindari',
#   'lonjakan',
#   'kasus'],
#  ['dosis',
#   'vaksin',
#   'pfizer',
#   'langsung',
#   'didistribusikan',
#   'ke',
#   'provinsi',
#   'oktober'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['sudah',
#   'lebih',
#   'dari',
#   'juta',
#   'dosis',
#   'vaksin',
#   'covid',
#   'disuntikkan',
#   'agustus'],
#  ['lebih', 'dari', 'juta', 'orang', 'sudah', 'divaksinasi'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'mei'],
#  ['tahap',
#   'ke',
#   'vaksin',
#   'covid',
#   'pfizer',
#   'tiba',
#   'di',
#   'bandara',
#   'soekarnohatta',
#   'dan',
#   'ahmad',
#   'yani'],
#  ['percepat', 'vaksinasi', 'stok', 'dan', 'distribusi', 'vaksin', 'digenjot'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['vaksinasi',
#   'presiden',
#   'harus',
#   'diulang',
#   'dan',
#   'hatihati',
#   'dengan',
#   'vaksinasi'],
#  ['alur',
#   'verifikasi',
#   'vaksinasi',
#   'bagi',
#   'wni',
#   'dan',
#   'wna',
#   'yang',
#   'divaksinasi',
#   'di',
#   'luar',
#   'negeri'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['vaksin',
#   'astrazeneca',
#   'aman',
#   'penghentian',
#   'sementara',
#   'hanya',
#   'pada',
#   'batch',
#   'ctmav'],
#  ['vaksin', 'covid', 'tidak', 'perlu', 'dikhawatirkan', 'masyarakat'],
#  ['tahap',
#   'ke',
#   'ribu',
#   'vaksin',
#   'astrazeneca',
#   'bantuan',
#   'pemerintah',
#   'australia',
#   'kembali',
#   'tiba',
#   'di',
#   'tanah',
#   'air'],
#  ['mal',
#   'mulai',
#   'dibuka',
#   'buat',
#   'yang',
#   'sudah',
#   'vaksin',
#   'prokes',
#   'jangan',
#   'kendor',
#   'nanti',
#   'tutup',
#   'lagi'],
#  ['pesepakbola',
#   'christian',
#   'eriksen',
#   'terkena',
#   'serangan',
#   'jantung',
#   'setelah',
#   'divaksin'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'februari'],
#  ['vaksinasi',
#   'covid',
#   'untuk',
#   'warga',
#   'non',
#   'dki',
#   'jakarta',
#   'di',
#   'istora',
#   'senayan'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'juni'],
#  ['vaksinasi',
#   'covid',
#   'di',
#   'indonesia',
#   'tembus',
#   'juta',
#   'dosis',
#   'sehari'],
#  ['vaksin',
#   'tahap',
#   'ke',
#   'tiba',
#   'bentuk',
#   'konsistensi',
#   'pemerintah',
#   'amankan',
#   'pasokan'],
#  ['hoaks',
#   'vaksin',
#   'yang',
#   'dipakai',
#   'jokowi',
#   'tidak',
#   'asli',
#   'karena',
#   'harus',
#   'menggunakan',
#   'alat',
#   'suntik'],
#  ['pemerintah',
#   'ajak',
#   'pihak',
#   'swasta',
#   'sukseskan',
#   'vaksin',
#   'merah',
#   'putih'],
#  ['apakah', 'vaksin', 'covid', 'adalah', 'obat'],
#  ['kedatangan',
#   'vaksin',
#   'tahap',
#   'ke',
#   'selain',
#   'untuk',
#   'masyarakat',
#   'vaksin',
#   'moderna',
#   'juga',
#   'untuk',
#   'dosis',
#   'ke',
#   'tenaga',
#   'kesehatan'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'agustus'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['masyarakat',
#   'suku',
#   'baduy',
#   'tidak',
#   'pernah',
#   'divaksin',
#   'dalam',
#   'ratusan',
#   'tahun'],
#  ['vaksin', 'covid', 'dapat', 'mengubah', 'warna', 'darah'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['tambahan',
#   'juta',
#   'dosis',
#   'vaksin',
#   'sinopharm',
#   'untuk',
#   'mendukung',
#   'kelancaran',
#   'program',
#   'vaksinasi',
#   'gotong',
#   'royong'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['apa', 'pentingnya', 'vaksin', 'bagi', 'manusia'],
#  ['ahli',
#   'pembuatan',
#   'vaksin',
#   'diawasi',
#   'ketat',
#   'untuk',
#   'memastikan',
#   'keamanannya'],
#  ['tahap', 'ke', 'tiba', 'ribu', 'dosis', 'vaksin', 'astrazeneca'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['tahap', 'awal', 'pengadaan', 'vaksin', 'covid'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'maret'],
#  ['sudah', 'divaksinasi', 'covid', 'begini', 'cara', 'unduh', 'sertifikatnya'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'september'],
#  ['juta',
#   'vaksin',
#   'bulk',
#   'covid',
#   'dari',
#   'sinovac',
#   'kembali',
#   'tiba',
#   'di',
#   'indonesia'],
#  ['bio',
#   'farma',
#   'produksi',
#   'vaksin',
#   'covid',
#   'dari',
#   'bahan',
#   'baku',
#   'vaksin',
#   'hasil',
#   'kerja',
#   'sama',
#   'dengan',
#   'sinovac'],
#  ['awas',
#   'hoaks',
#   'bahaya',
#   'vaksin',
#   'pfizer',
#   'bagi',
#   'bayi',
#   'yang',
#   'disusui'],
#  ['data', 'vaksinasi', 'covid', 'update', 'per', 'oktober'],
#  ['kandidat',
#   'vaksin',
#   'merah',
#   'putih',
#   'akan',
#   'segera',
#   'diproses',
#   'lebih',
#   'lanjut'],
#  ['sudah', 'divaksin', 'covid', 'lakukan', 'hal', 'berikut'],
#  ['ingin',
#   'vaksinasi',
#   'tapi',
#   'fobia',
#   'jarum',
#   'suntik',
#   'begini',
#   'cara',
#   'mengatasinya'],
#  ['akselerasi', 'vaksin', 'covid', 'karya', 'anak', 'bangsa'],
#  ['datang',
#   'lagi',
#   'vaksin',
#   'sinopharm',
#   'dan',
#   'astrazeneca',
#   'ke',
#   'indonesia',
#   'juli'],
#  ['persiapan',
#   'logistik',
#   'dan',
#   'sdm',
#   'vaksinasi',
#   'covid',
#   'dilakukan',
#   'dengan',
#   'matang'],
#  ['awas',
#   'hoaks',
#   'bill',
#   'gates',
#   'menolak',
#   'vaksinasi',
#   'covid',
#   'untuk',
#   'anaknya'],
#  ['akselerasi',
#   'vaksinasi',
#   'covid',
#   'kunci',
#   'tekan',
#   'angka',
#   'kesakitan',
#   'kematian',
#   'pada',
#   'lansia'],
#  ['vaksin',
#   'terbukti',
#   'mampu',
#   'melindungi',
#   'diri',
#   'dari',
#   'mutasi',
#   'virus',
#   'covid'],
#  ...]

# %% [markdown]
# Spell Normalization

# %%
# penyeragaman kata yang memiliki makna yang sama namun penulisan yang berbeda

normalizad_word = pd.read_excel("normalisasi.xlsx")
normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(doc):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in doc]

datavacc['judul'] = datavacc['judul'].apply(normalized_term) 
datavacc.head(2)
# Out:
#                                                judul    tanggal  \
# 0  [mui, larang, gunakan, vaksin, covid, asal, ti...  07-Oct-20
# 1  [menteri, agama, terkena, covid, hanya, hoaks,...  07-Oct-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1

# %%
datavacc.to_csv("Normalisasi-justtitle.csv", index=False)

# %% [markdown]
# Stopword Removal

# %%
from nltk.corpus import stopwords


#get stopword indonesia
list_stopwords = stopwords.words('indonesian')
# read data stopword tambahan from csv
txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# konversi kata stopword dari file csv ke list
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# mengakhiri list ke dictionary
list_stopwords = set(list_stopwords)

# fungsi untuk menghapus stopword
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

datavacc['judul'] = datavacc['judul'].apply(stopwords_removal) 
datavacc.head(2)
# Out:
#                                                judul    tanggal  \
# 0             [mui, larang, vaksin, covid, tiongkok]  07-Oct-20
# 1  [menteri, agama, terkena, covid, hoaks, rakyat...  07-Oct-20
#
#   Kategori Sumber                                               link  label
# 0        Facebook  https://covid19.go.id/artikel/2020/10/07/awas-...      1
# 1  pesan whatsapp                                                  -      1

# %%
datavacc.to_csv("StopwordRemoval-justtitle.csv", index=False)

# %% [markdown]
# Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in datavacc['judul']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

datavacc['judul'] = datavacc['judul'].swifter.apply(get_stemmed_term)
# Out:
# 1788
# ------------------------
# mui : mui
# larang : larang
# vaksin : vaksin
# covid : covid
# tiongkok : tiongkok
# menteri : menteri
# agama : agama
# terkena : kena
# hoaks : hoaks
# rakyat : rakyat
# divaksin : vaksin
# mengubah : ubah
# dna : dna
# manusia : manusia
# jawa : jawa
# barat : barat
# daerah : daerah
# disuntik : suntik
# bpom : bpom
# halangi : halang
# penyuntikan : sunti
# berbasis : bas
# mrna : mrna
# rusak : rusak
# masyarakat : masyarakat
# zimbabwe : zimbabwe
# penyakit : sakit
# kulit : kulit
# berair : air
# akibat : akibat
# indonesia : indonesia
# mengalami : alami
# dibunuh : bunuh
# china : china
# mengandung : kandung
# aluminium : aluminium
# merusak : rusak
# otak : otak
# disimpan : simpan
# suhu : suhu
# derajat : derajat
# memanipulasi : manipulasi
# gen : gen
# pendaftaran : daftar
# penerima : terima
# sinovac : sinovac
# juta : juta
# eropa : eropa
# idi : idi
# tolak : tolak
# singapura : singapura
# lakukan : laku
# vaksinasi : vaksinasi
# bandara : bandara
# changi : changi
# formaldehida : formaldehida
# menyebabkan : sebab
# leukemia : leukemia
# anak : anak
# buatan : buat
# memilih : pilih
# impor : impor
# jerman : jerman
# presiden : presiden
# jokowi : jokowi
# perbandingan : banding
# penemuan : temu
# hiv : hiv
# flu : flu
# kanker : kanker
# gratis : gratis
# peserta : serta
# bpjs : bpjs
# aktif : aktif
# beli : beli
# paus : paus
# fransiskus : fransiskus
# masuk : masuk
# surga : surga
# bill : bill
# gates : gates
# ceo : ceo
# pfizer : pfizer
# menolak : tolak
# pemerintah : perintah
# rumania : rumania
# tutup : tutup
# pusat : pusat
# imbas : imbas
# penolakan : tolak
# persen : persen
# warga : warga
# meninggal : tinggal
# dunia : dunia
# website : website
# cdc : cdc
# amerika : amerika
# cacat : cacat
# sakit : sakit
# parah : parah
# pasca : pasca
# ulama : ulama
# aceh : aceh
# haramkan : haram
# nomor : nomor
# rekening : rekening
# ponsel : ponsel
# diblokir : blokir
# joko : joko
# widodo : widodo
# dikabarkan : kabar
# kejangkejang : kejangkejang
# berbahaya : bahaya
# polisorbat : polisorbat
# orang : orang
# menjalani : jalan
# mematuhi : patuh
# protokol : protokol
# kesehatan : sehat
# danramil : danramil
# kebomas : kebomas
# gresik : gresik
# air : air
# kelapa : kelapa
# hijau : hijau
# penawar : tawar
# gagal : gagal
# diulang : ulang
# gereja : gereja
# thailand : thailand
# menangis : menang
# sebabkan : sebab
# lamban : lamban
# berpikir : pikir
# susah : susah
# menghafal : hafal
# who : who
# moderna : moderna
# sistem : sistem
# operasi : operasi
# dirancang : rancang
# agen : agen
# biologis : biologis
# bupati : bupati
# pasuruan : pasuruan
# alami : alami
# suntik : suntik
# meledak : ledak
# kompensasi : kompensasi
# surat : surat
# elektronik : elektronik
# mengatasnamakan : mengatasnamakan
# ipd : ipd
# balitbangkes : balitbangkes
# terkait : kait
# pemberian : beri
# pesan : pesan
# berantai : beranta
# lansia : lansia
# kantor : kantor
# bppsdmk : bppsdmk
# jakarta : jakarta
# potasium : potasium
# organ : organ
# tubuh : tubuh
# data : data
# tim : tim
# medis : medis
# lupa : lupa
# jenis : jenis
# sertifikat : sertifikat
# nondki : nondki
# corona : corona
# senayan : senayan
# whatsapp : whatsapp
# informasi : informasi
# ajakan : aja
# bio : bio
# farma : farma
# mudah : mudah
# terinfeksi : infeksi
# larangan : larang
# minum : minum
# obat : obat
# jantung : jantung
# jadwal : jadwal
# gedung : gedung
# pakuan : paku
# bandung : bandung
# pengumuman : umum
# puskesmas : puskesmas
# kramat : kramat
# jati : jati
# guru : guru
# honorer : honorer
# leles : leles
# garut : garut
# lumpuh : lumpuh
# negara : negara
# melarang : larang
# penggunaan : guna
# astrazeneca : astrazeneca
# berbentuk : bentuk
# sirup : sirup
# takut : takut
# makan : makan
# tape : tape
# hilangkan : hilang
# fungsi : fungsi
# kelompok : kelompok
# non : non
# rumah : rumah
# santo : santo
# borromeus : borromeus
# kota : kota
# menyusui : susu
# dijual : jual
# online : online
# shopee : shopee
# malaysia : malaysia
# singkat : singkat
# mandiri : mandiri
# seharga : harga
# rupiah : rupiah
# ribu : ribu
# massal : massal
# dinas : dinas
# provinsi : provinsi
# sumatera : sumatera
# utara : utara
# penyintas : sintas
# divaksinasi : vaksinasi
# isolasi : isolasi
# menunggu : tunggu
# terapi : terapi
# instruksi : instruksi
# mutasi : mutasi
# virus : virus
# terbuka : buka
# bahaya : bahaya
# percobaan : coba
# wajib : wajib
# memiliki : milik
# izin : izin
# darurat : darurat
# tingkatkan : tingkat
# kadar : kadar
# limfosit : limfosit
# mematikan : mati
# disfungsi : disfungsi
# ereksi : ereksi
# pria : pria
# menularkan : tular
# reproduksi : reproduksi
# menstruasi : menstruasi
# turunkan : turun
# imun : imun
# uji : uji
# coba : coba
# kematian : mati
# mendadak : dadak
# dokter : dokter
# wafat : wafat
# jam : jam
# registrasi : registrasi
# usia : usia
# rs : rs
# hermina : hermina
# kemayoran : mayor
# pedulilindungiid : pedulilindungiid
# covaxin : covaxin
# india : india
# disetujui : tuju
# benda : benda
# bermagnet : magnet
# menempel : tempel
# lengan : lengan
# magnet : magnet
# sebarkan : sebar
# kontak : kontak
# fisik : fisik
# dideteksi : deteksi
# bluetooth : bluetooth
# membunuh : bunuh
# memusnahkan : musnah
# populasi : populasi
# gangguan : ganggu
# wanita : wanita
# mati : mati
# sm : sm
# survei : survei
# serikat : serikat
# umur : umur
# semarang : semarang
# menciptakan : cipta
# varian : varian
# masker : masker
# as : as
# video : video
# eric : eric
# tohir : tohir
# chip : chip
# bius : bius
# akibatkan : akibat
# dilarang : larang
# pill : pill
# kb : kb
# sitotoksik : sitotoksik
# auri : aur
# colomadu : colomadu
# teh : teh
# daun : daun
# pinus : pinus
# hentikan : henti
# efek : efek
# infografis : infografis
# manfaatkan : manfaat
# kemenkes : kemenkes
# form : form
# khusus : khusus
# ktp : ktp
# tangerang : tangerang
# selatan : selatan
# christian : christian
# eriksen : eriksen
# serangan : serang
# tewas : tewas
# durian : durian
# samping : samping
# pertanda : tanda
# sehat : sehat
# anakanak : anakanak
# rsud : rsud
# abdul : abdul
# wahab : wahab
# sjahranie : sjahranie
# samarinda : samarinda
# dibandingkan : banding
# skotlandia : skotlandia
# menyelamatkan : selamat
# pengguna : guna
# pandemi : pandemi
# diuji : uji
# alumni : alumni
# sekolah : sekolah
# kolese : kolese
# kanisius : kanisius
# gelar : gelar
# delta : delta
# disebabkan : sebab
# bayi : bayi
# muda : muda
# dirawat : rawat
# mengecek : ecek
# gelombang : gelombang
# syarat : syarat
# kartu : kartu
# genetika : genetika
# pelaksanaan : laksana
# islam : islam
# fitrah : fitrah
# al : al
# fikri : fikri
# on : on
# the : the
# spot : spot
# itc : itc
# depok : depok
# ribuan : ribu
# perawat : awat
# belanda : belanda
# manjur : manjur
# pindah : pindah
# rusia : rusia
# wajibkan : wajib
# warganya : warga
# bantuan : bantu
# pemegang : pegang
# lempake : lempake
# mengadakan : ada
# gor : gor
# sempaja : sempaja
# direktur : direktur
# pengendalian : kendali
# suku : suku
# pedalaman : dalam
# badui : badui
# pernyataan : nyata
# negatif : negatif
# ombudsman : ombudsman
# republik : republik
# pasien : pasien
# positif : positif
# new : new
# south : south
# wales : wales
# australia : australia
# solusi : solusi
# mengendalikan : kendali
# herd : herd
# immunity : immunity
# terpapar : papar
# rentan : rentan
# mengonsumsi : konsumsi
# makanan : makan
# minuman : minum
# alkohol : alkohol
# soda : soda
# hasil : hasil
# tes : tes
# balita : balita
# upaya : upaya
# pemusnahan : musnah
# umat : umat
# turki : turki
# dosis : dosis
# nusantara : nusantara
# rsup : rsup
# ham : ham
# agustus : agustus
# september : september
# panggilan : panggil
# telepon : telepon
# menyerang : serang
# darah : darah
# putih : putih
# lemah : lemah
# anaknya : anak
# scan : scan
# qr : qr
# bekas : bekas
# suntikan : sunti
# undangan : undang
# booster : booster
# ditanam : tanam
# serukan : seru
# penarikan : tari
# pemberlakuan : laku
# pembelian : beli
# bbm : bbm
# spbu : spbu
# kental : kental
# memperpendek : pendek
# keguguran : gugur
# mri : mri
# kali : kali
# pemahaman : paham
# albert : albert
# bourla : bourla
# mengimunisasi : imunisasi
# pilot : pilot
# pesawat : pesawat
# lines : les
# penerbangan : terbang
# antena : antena
# g : g
# pengendali : kendali
# studi : studi
# fda : fda
# tertular : tular
# akui : aku
# cina : cina
# menghancurkan : hancur
# mesin : mesin
# verifikasi : verifikasi
# paspor : paspor
# laporan : lapor
# kebutaan : buta
# remaja : remaja
# inggris : inggris
# terlahir : lahir
# kosong : kosong
# menerima : terima
# pemberitaan : berita
# peredaran : edar
# foto : foto
# penampakan : tampak
# protes : protes
# melbourne : melbourne
# pingsan : pingsan
# perdana : perdana
# mengantre : antre
# demo : demo
# brasil : brasil
# fenomena : fenomena
# ade : ade
# warna : warna
# berubah : ubah
# tukul : tukul
# pendarahan : darah
# ditipu : tipu
# internasional : internasional
# judul : judul
# berita : berita
# itv : itv
# wajah : wajah
# merah : merah
# berhalangan : halang
# krl : krl
# tertua : tua
# era : era
# utsmani : utsmani
# m : m
# simpsons : simpsons
# memprediksi : prediksi
# agenda : agenda
# peluncuran : luncur
# mendorong : dorong
# ketakutan : takut
# antivaksin : antivaksin
# antrean : antre
# ilmuwan : ilmuwan
# menular : tular
# maruf : maruf
# amin : amin
# neraka : neraka
# siswa : siswa
# sidoarjo : sidoarjo
# politikus : politikus
# bells : bells
# palsy : palsy
# daftar : daftar
# pedoman : pedoman
# berbayar : bayar
# speedlab : speedlab
# dokumen : dokumen
# nhs : nhs
# tingkat : tingkat
# reaksi : reaksi
# buruk : buruk
# gradhika : gradhika
# bhakti : bhakti
# temukan : temu
# palsu : palsu
# beredar : edar
# rspal : rspal
# dr : dr
# ramelan : ramelan
# surabaya : surabaya
# ditutup : tutup
# kru : kru
# aman : aman
# efektif : efektif
# rekayasa : rekayasa
# bermutasi : mutasi
# timbulkan : timbul
# ambil : ambil
# bansos : bansos
# tunai : tunai
# pos : pos
# bawa : bawa
# bukti : bukti
# royal : royal
# plaza : plaza
# klarifikasi : klarifikasi
# perubahan : ubah
# tenaga : tenaga
# rsab : rsab
# harapan : harap
# kipi : kipi
# berat : berat
# grafena : grafena
# oksida : oksida
# suasana : suasana
# anti : anti
# prancis : prancis
# barcode : barcode
# mengontrol : kontrol
# setujui : tuju
# karyawan : karyawan
# pt : pt
# freeport : freeport
# kiriman : kirim
# menyusut : susut
# serentak : serentak
# kompas : kompas
# tv : tv
# mike : mike
# tyson : tyson
# pakai : pakai
# kaos : kaos
# bertuliskan : tulis
# muslim : muslim
# nonmuslim : nonmuslim
# berbeda : beda
# terima : terima
# donasi : donasi
# persatuan : satu
# emirat : emirat
# arab : arab
# perkenalkan : kenal
# juru : juru
# bicara : bicara
# horas : horas
# sentra : sentra
# hadir : hadir
# medan : medan
# ayo : ayo
# persiapan : siap
# menikah : meni
# perjalanan : jalan
# satgas : satgas
# trombo : trombo
# emboli : emboli
# berkaitan : kait
# update : update
# april : april
# sri : sri
# mulyani : mulyani
# pencitraan : citra
# tp : tp
# kamera : kamera
# boong : boong
# jarum : jarum
# ga : ga
# isi : isi
# nya : nya
# mengacu : acu
# eua : eua
# badan : badan
# pom : pom
# oktober : oktober
# penduduk : duduk
# lengkap : lengkap
# cegah : cegah
# risiko : risiko
# paket : paket
# ikthiar : ikthiar
# lawan : lawan
# kedatangan : datang
# tahap : tahap
# mal : mal
# optimal : optimal
# menekan : tekan
# peluang : peluang
# penularan : tular
# maret : maret
# ppkm : ppkm
# kejar : kejar
# target : target
# tni : tni
# rekrut : rekrut
# cakupan : cakup
# penyelenggara : selenggara
# pon : pon
# xx : xx
# papua : papua
# percepatan : cepat
# tanah : tanah
# awas : awas
# kalinya : kali
# tunjukkan : tunjuk
# mayoritas : mayoritas
# bersedia : sedia
# menag : menag
# sejalan : jalan
# spirit : spirit
# menjaga : jaga
# kehidupan : hidup
# kandungan : kandung
# juni : juni
# februari : februari
# produksi : produksi
# portal : portal
# corporaterealtyco : corporaterealtyco
# mei : mei
# korona : korona
# terhalang : halang
# artikel : artikel
# cnn : cnn
# merekomendasikan : rekomendasi
# disuntikkan : suntik
# alat : alat
# kelamin : kelamin
# hidup : hidup
# jurus : jurus
# menyelesaikan : selesai
# cek : cek
# lokasi : lokasi
# faskes : faskes
# pulau : pulau
# bali : bal
# httpscovidgoidfaskesvaksin : httpscovidgoidfaskesvaksin
# perusahaan : usaha
# biofarmasi : biofarmasi
# inc : inc
# mengembangkan : kembang
# munculnya : muncul
# dukung : dukung
# astrazenecca : astrazenecca
# datangkan : datang
# mandul : mandul
# kelumpuhan : lumpuh
# juli : juli
# wni : wni
# wna : wna
# negeri : negeri
# dukungan : dukung
# menyukseskannya : sukses
# pilihpilih : pilihpilih
# manfaatnya : manfaat
# soekarnohatta : soekarnohatta
# ahmad : ahmad
# yani : yani
# tanggal : tanggal
# diplomasi : diplomasi
# dilanjutkan : lanjut
# mengawal : awal
# microchip : microchip
# magnetik : magnetik
# sambut : sambut
# menlu : menlu
# mekanisme : mekanisme
# dosesharing : dosesharing
# bumn : bumn
# peringkat : peringkat
# keempat : empat
# prinsip : prinsip
# utama : utama
# korea : korea
# kelabakan : laba
# lihat : lihat
# persatu : satu
# masjid : masjid
# prioritaskan : prioritas
# donor : donor
# sadarkan : sadar
# rsal : rsal
# rekomendasi : rekomendasi
# hindari : hindar
# tekanan : tekan
# ditingkatkan : tingkat
# batch : batch
# ctmav : ctmav
# penuhi : penuh
# mutu : mutu
# pemda : pemda
# percepat : cepat
# pendidik : didik
# pembelajaran : ajar
# tatap : tatap
# muka : muka
# ptm : ptm
# terbatas : batas
# misinformasi : misinformasi
# nama : nama
# sesuai : sesuai
# covax : covax
# uni : uni
# kawal : kawal
# kesiapan : kesiap
# sarana : sarana
# terbaik : baik
# beda : beda
# jarak : jarak
# konsumsi : konsumsi
# lindungi : lindung
# sinopharm : sinopharm
# ketua : ketua
# komite : komite
# kpcpen : kpcpen
# airlangga : airlangga
# hartarto : hartarto
# disarankan : saran
# menunda : tunda
# kekhawatiran : khawatir
# tujuannya : tuju
# kenali : kenal
# gejala : gejala
# long : long
# manfaat : manfaat
# kemenkesunicef : kemenkesunicef
# tandatangani : tandatangani
# kerja : kerja
# pengadaan : ada
# terjangkau : jangkau
# kependidikan : didik
# penyandang : sandang
# disabilitas : disabilitas
# jawabali : jawabali
# suntikkan : suntik
# perjanjian : janji
# bilateral : bilateral
# kadin : kadin
# terdaftar : daftar
# gotong : gotong
# royong : royong
# bermanfaat : manfaat
# distribusi : distribusi
# dikelola : kelola
# terintegrasi : integrasi
# bohong : bohong
# langsung : langsung
# didistribusikan : distribusi
# delapan : delapan
# strategi : strategi
# pekerja : kerja
# seni : seni
# klinis : klinis
# kandidat : kandidat
# pengisian : isi
# wilayah : wilayah
# trumon : trumon
# raya : raya
# nakes : nakes
# publik : publik
# miliar : miliar
# diterima : terima
# telapak : telapak
# kaki : kaki
# relawan : rawan
# melepuh : lepuh
# bayar : bayar
# potensi : potensi
# kolaboratif : kolaboratif
# baiknya : baik
# menundanunda : menundanunda
# probolinggo : probolinggo
# serumah : rumah
# program : program
# mempertimbangkan : timbang
# ketersediaan : sedia
# vaksinator : vaksinator
# kesuksesan : sukses
# dorong : dorong
# pemulihan : pulih
# ekonomi : ekonomi
# seputar : putar
# hibah : hibah
# bentuk : bentuk
# tanggung : tanggung
# pengusaha : usaha
# kejang : kejang
# optimis : optimis
# negaranya : negara
# periksa : periksa
# httpssidinfovaksin : httpssidinfovaksin
# pecah : pecah
# rekor : rekor
# tembus : tembus
# angka : angka
# kolaborasi : kolaborasi
# diharapkan : harap
# pfizerbiontech : pfizerbiontech
# kumham : kumham
# hapus : hapus
# sanksi : sanksi
# pidana : pidana
# buah : buah
# megawati : megawati
# amankan : aman
# pemangku : mang
# kepentingan : penting
# patuhi : patuh
# ketentuan : tentu
# perpres : pres
# no : no
# pastikan : pasti
# awak : awak
# media : media
# teruji : uji
# minim : minim
# berkhasiat : khasiat
# halal : halal
# upayakan : upaya
# pemerataan : perata
# nasional : nasional
# meningkatkan : tingkat
# imunitas : imunitas
# kakek : kakek
# ditahan : tahan
# memakai : pakai
# diperkuat : kuat
# pencegahan : cegah
# ditemukan : temu
# tambahan : tambah
# bulk : bulk
# menjamin : jamin
# kelancaran : lancar
# keamanan : aman
# khasiat : khasiat
# genosida : genosida
# kriteria : kriteria
# penetapan : tetap
# emergency : emergency
# use : use
# authorization : authorization
# penangkal : tangkal
# racun : racun
# penanganan : tangan
# ditanggung : tanggung
# lahirnya : lahir
# keras : keras
# petugas : tugas
# pelayanan : layan
# dilaksanakan : laksana
# harga : harga
# mahal : mahal
# brazil : brazil
# ciri : ciri
# penyebab : sebab
# korban : korban
# pedulilindungi : pedulilindungi
# memudahkan : mudah
# mengakses : akses
# fasilitas : fasilitas
# disebarkan : sebar
# pembuatan : buat
# group : group
# info : info
# pembagian : bagi
# optimalisasi : optimalisasi
# pemenuhan : penuh
# perbedaan : beda
# kemasan : kemas
# komorbid : komorbid
# syaratnya : syarat
# penjelasan : jelas
# sehubungan : hubung
# penyebaran : sebar
# beresiko : resiko
# perempuan : perempuan
# menko : menko
# pmk : pmk
# tekankan : tekan
# memprioritaskan : prioritas
# garda : garda
# coronavac : coronavac
# lulus : lulus
# sertifikasi : sertifikasi
# lot : lot
# release : release
# cari : cari
# dampak : dampak
# kipicovidgoid : kipicovidgoid
# tinjau : tinjau
# kantongi : kantong
# bertengger : tengger
# munarman : munarman
# udah : udah
# anggota : anggota
# brimob : brimob
# maluku : malu
# menghilang : hilang
# proses : proses
# yuk : yuk
# fakta : fakta
# mitos : mitos
# hewan : hewan
# terbukti : bukti
# perlindungan : lindung
# pelajar : ajar
# dipercepat : cepat
# puluh : puluh
# ampuh : ampuh
# t : t
# setahun : tahun
# melanda : landa
# duluan : duluan
# terlena : lena
# cepat : cepat
# picu : picu
# kekebalan : kebal
# kejadian : jadi
# ikutan : ikut
# imunisasi : imunisasi
# peneliti : teliti
# kemandulan : mandul
# bahan : bahan
# baku : baku
# diantar : antar
# mengantar : antar
# calon : calon
# jemaah : jemaah
# haji : haji
# melengkapi : lengkap
# kurangi : kurang
# bikin : bikin
# degdegan : degdegan
# skema : skema
# anafilaktik : anafilaktik
# pasokan : pasok
# teguhkan : teguh
# hadapi : hadap
# tahapan : tahap
# syuting : syuting
# film : film
# horor : horor
# euforia : euforia
# testing : testing
# tracing : tracing
# kabupatenkota : kabupatenkota
# httpsvaksinkemkesgoidsckab : httpsvaksinkemkesgoidsckab
# dexamethasone : dexamethasone
# murah : murah
# pascavaksinasi : pascavaksinasi
# kebanyakan : banyak
# pegal : pegal
# lapar : lapar
# ngantuk : ngantuk
# alasan : alas
# klaster : klaster
# peparnas : peparnas
# sel : sel
# direkomendasikan : rekomendasi
# infrastruktur : infrastruktur
# sdm : sdm
# jepang : jepang
# astrazaneca : astrazaneca
# ctmva : ctmva
# netanyahu : netanyahu
# mencukupi : cukup
# kebutuhan : butuh
# elisa : elisa
# granato : granato
# kelinci : kelinci
# kopit : kopit
# ptk : ptk
# libur : libur
# nataru : nataru
# kian : kian
# hamil : hamil
# mencegah : cegah
# mewabah : wabah
# kesembuhan : sembuh
# infeksi : infeksi
# protein : protein
# spike : spike
# maskapai : maskapai
# penumpang : tumpang
# kemajuan : maju
# teknologi : teknologi
# kondisi : kondisi
# gubernur : gubernur
# facility : facility
# kirimkan : kirim
# semangat : semangat
# menang : menang
# menutup : tutup
# perhitungan : hitung
# drivethru : drivethru
# tandai : tanda
# pelaku : laku
# parekraf : parekraf
# terindikasi : indikasi
# pembekuan : beku
# dprd : dprd
# mimika : mimika
# pemilik : milik
# korongna : korongna
# salah : salah
# vaksinkemkesgoid : vaksinkemkesgoid
# terbaru : baru
# jahat : jahat
# rezim : rezim
# terungkap : ungkap
# logistik : logistik
# grup : grup
# proteksi : proteksi
# siapkan : siap
# rawat : rawat
# inap : inap
# diperluas : luas
# nik : nik
# pulihkan : pulih
# bangkitkan : bangkit
# penambahan : tambah
# indikator : indikator
# capaian : capai
# menetapkan : tetap
# level : level
# tersedia : sedia
# selandia : selandia
# survey : survey
# suarakan : suara
# kesetaraan : tara
# peruntukkan : untuk
# ayam : ayam
# aturan : atur
# sasaran : sasar
# bebankan : beban
# pengunjung : unjung
# mengakomodir : mengakomodir
# masukan : masuk
# saraf : saraf
# panglima : panglima
# menkes : menkes
# apresiasi : apresiasi
# keikutsertaan : keikutsertaan
# litbangkes : litbangkes
# terbitkan : terbit
# suci : suci
# doni : doni
# monardo : monardo
# fatwa : fatwa
# swab : swab
# batalkan : batal
# puasa : puasa
# pelni : pelni
# mrc : mrc
# butuh : butuh
# atasi : atas
# dicetak : cetak
# alasanya : alasanya
# terjaga : jaga
# kualitasnya : kualitas
# berusia : usia
# fokus : fokus
# mendaftar : daftar
# link : link
# linimasa : linimasa
# kronologi : kronologi
# syekh : syekh
# ali : ali
# jabar : jabar
# beliau : beliau
# disangka : sangka
# karna : karna
# buku : buku
# saku : saku
# ahli : ahli
# cairan : cair
# ketiga : tiga
# separuh : paruh
# bertemu : temu
# ragu : ragu
# membangun : bangun
# akselerasi : akselerasi
# putri : putri
# vladimir : vladimir
# putin : putin
# terciptanya : cipta
# berafiliasi : afiliasi
# kecuali : kecuali
# lampu : lampu
# kedepankan : depan
# edukasi : edukasi
# pm : pm
# validasi : validasi
# khasiatnya : khasiat
# vitamin : vitamin
# ditetapkan : tetap
# efektivitas : efektivitas
# erick : erick
# thohir : thohir
# seumur : umur
# ber : ber
# keselamatan : selamat
# pembaruan : baru
# dashboard : dashboard
# pantau : pantau
# httpsvaksinkemkesgoid : httpsvaksinkemkesgoid
# jumat : jumat
# sms : sms
# dikirim : kirim
# i : i
# lolos : lolos
# johnson : johnson
# nyata : nyata
# komitmen : komitmen
# tips : tips
# reisa : reisa
# atlet : atlet
# juang : juang
# kejuaraan : juara
# rantai : rantai
# dingin : dingin
# cold : cold
# chain : chain
# kebijakan : bijak
# ticketmaster : ticketmaster
# menghadiri : hadir
# konser : konser
# tentara : tentara
# angkatan : angkat
# laut : laut
# dimall : dimall
# tanggrek : tanggrek
# stok : stok
# cermat : cermat
# alokasikan : alokasi
# anggaran : anggar
# berupaya : upaya
# mengurangi : kurang
# ketergantungan : gantung
# langkah : langkah
# ganda : ganda
# kemenristekbrin : kemenristekbrin
# pengembangan : kembang
# mengobati : obat
# serviks : serviks
# penerimaan : terima
# armand : armand
# maulana : maulana
# cak : cak
# lontong : lontong
# nia : nia
# dinata : dinata
# kreatif : kreatif
# antivirus : antivirus
# genome : genome
# berisiko : risiko
# paralel : paralel
# kolektif : kolektif
# mengantisipasi : antisipasi
# mempengaruhi : pengaruh
# efikasi : efikasi
# sidinfovaksin : sidinfovaksin
# platform : platform
# agregator : agregator
# berburu : buru
# merek : merek
# mempercepat : cepat
# layani : layan
# prokes : prokes
# bertahap : tahap
# kemenristek : kemenristek
# brin : brin
# monitor : monitor
# alumunium : alumunium
# perancis : perancis
# swasta : swasta
# berpeluang : peluang
# sukseskan : sukses
# rapat : rapat
# cia : cia
# dewasa : dewasa
# kunci : kunci
# keberhasilan : hasil
# menkominfo : menkominfo
# ruang : ruang
# didorong : dorong
# sinergikan : sinergi
# lembaga : lembaga
# penelitian : teliti
# majelis : majelis
# berkomitmen : komitmen
# kehalalan : halal
# banyaknya : banyak
# muncul : muncul
# melindungi : lindung
# generasi : generasi
# seberangi : seberang
# samudra : samudra
# dilindungi : lindung
# peti : peti
# kemas : kemas
# memenuhi : penuh
# standar : standar
# kualitas : kualitas
# ramadhan : ramadhan
# halhal : halhal
# penyitas : penyitas
# ipsos : ipsos
# gsp : gsp
# pribadi : pribadi
# kendalikan : kendali
# wabah : wabah
# disiapkan : siap
# kebut : kebut
# perluas : luas
# menghapus : hapus
# domisili : domisili
# bogor : bogor
# tergesa : gesa
# keampuhan : ampuh
# dipakai : pakai
# asli : asli
# perkuat : kuat
# capai : capai
# tunggu : tunggu
# keputusan : putus
# wwwpedulilindungiidperiksasertifikat : wwwpedulilindungiidperiksasertifikat
# pengawasan : awas
# menerapkan : terap
# januari : januari
# sehari : hari
# merugikan : rugi
# donald : donald
# trump : trump
# umumkan : umum
# roche : roche
# medical : medical
# company : company
# meluncurkan : luncur
# jutaan : juta
# minggu : minggu
# melacak : lacak
# pake : pake
# ampulan : ampul
# didalam : dalam
# box : box
# spuit : spuit
# sdh : sdh
# kekerasan : keras
# polisi : polisi
# aksi : aksi
# antimasker : antimasker
# london : london
# catat : catat
# membutuhkan : butuh
# diawali : awal
# pedagang : dagang
# abang : abang
# prioritas : prioritas
# menangani : tangan
# formulir : formulir
# resmi : resmi
# ppsdmk : ppsdmk
# fiskal : fiskal
# efektivitasnya : efektivitas
# meragukan : ragu
# peta : peta
# jalan : jalan
# memotivasi : motivasi
# jaket : jaket
# dki : dki
# mengakselerasi : akselerasi
# sejuta : juta
# didukung : dukung
# jalur : jalur
# pelosok : pelosok
# bantu : bantu
# hilirisasi : hilir
# komersialisasi : komersialisasi
# ventilator : ventilator
# kembangkan : kembang
# pasar : pasar
# tumbuhkan : tumbuh
# belanja : belanja
# pengingat : ingat
# pungli : pungli
# lapor : lapor
# pembesaran : besar
# bersamaan : sama
# sukses : sukses
# dibarengi : bareng
# kepatuhan : patuh
# respon : respon
# vagal : vagal
# palestina : palestina
# penemu : temu
# menjangkau : jangkau
# disinformasi : disinformasi
# ilegal : ilegal
# bersertifikasi : sertifikasi
# injeksi : injeksi
# membatalkan : batal
# curah : curah
# maksudnya : maksud
# gandeng : gandeng
# elemen : elemen
# pandangan : pandang
# menggugat : gugat
# bermasalah : masalah
# tangkapan : tangkap
# layar : layar
# memberitakan : berita
# kabar : kabar
# karya : karya
# bangsa : bangsa
# multilateral : multilateral
# habis : habis
# simpan : simpan
# dibolehkan : boleh
# mubah : mubah
# pelacakan : lacak
# hati : hati
# melemahkan : lemah
# kekuatan : kuat
# wujud : wujud
# sayangi : sayang
# temani : teman
# segerakan : segera
# ditekan : tekan
# diancam : ancam
# keluarkan : keluar
# wawancara : wawancara
# ringan : ringan
# distribusikan : distribusi
# konsorsium : konsorsium
# riset : riset
# inovasi : inovasi
# berkolaborasi : kolaborasi
# bangun : bangun
# kemandirian : mandiri
# zifivax : zifivax
# syaratsyarat : syaratsyarat
# perlambat : lambat
# dubes : dubes
# ri : ri
# insya : insya
# allah : allah
# kesakitan : sakit
# temannya : teman
# menentukan : tentu
# tunda : tunda
# asas : asas
# kehatihatian : kehatihatian
# dialami : alami
# aspek : aspek
# disiplin : disiplin
# transparansi : transparansi
# pengelolaan : kelola
# zat : zat
# pendidikan : didik
# kendor : kendor
# muhammadiyah : muhammadiyah
# nonislam : nonislam
# sebulan : bulan
# sembuh : sembuh
# pemenang : menang
# c : c
# lonjakan : lonjak
# digenjot : genjot
# hatihati : hatihati
# alur : alur
# penghentian : henti
# dikhawatirkan : khawatir
# dibuka : buka
# pesepakbola : pesepakbola
# istora : istora
# konsistensi : konsistensi
# ajak : ajak
# baduy : baduy
# ratusan : ratus
# mendukung : dukung
# diawasi : awas
# ketat : ketat
# keamanannya : aman
# unduh : unduh
# sertifikatnya : sertifikat
# disusui : susu
# diproses : proses
# fobia : fobia
# mengatasinya : atas
# matang : matang
# tekan : tekan
# unggah : unggah
# medsos : medsos
# halalkan : halal
# ikhtiar : ikhtiar
# krusial : krusial
# laju : laju
# merata : rata
# mengikuti : ikut
# zona : zona
# miliki : milik
# opsi : opsi
# faktor : faktor
# berkualitas : kualitas
# diprioritaskan : prioritas
# khawatir : khawatir
# klinik : klinik
# vero : vero
# ikuti : ikut
# prosedur : prosedur
# kaidah : kaidah
# ilmiah : ilmiah
# hilang : hilang
# sabang : sabang
# merauke : merauke
# darahku : darah
# vaksinnya : vaksin
# situs : situs
# pedulilindungiqcom : pedulilindungiqcom
# dana : dana
# pondok : pondok
# pesantren : pesantren
# laksanakan : laksana
# direncanakan : rencana
# haram : haram
# penerimanya : terima
# menristekkepala : menristekkepala
# saksikan : saksi
# pendatanganan : pendatanganan
# kesepakatan : sepakat
# pendirian : diri
# pabrik : pabrik
# katalis : katalis
# kunjungan : kunjung
# semangkin : semangkin
# gawat : gawat
# perluasan : luas
# dpt : dpt
# palembang : palembang
# ditarget : target
# rampung : rampung
# layanan : layan
# pravaksinasi : pravaksinasi
# pengakuan : aku
# menyebut : sebut
# hutang : hutang
# plongaplongo : plongaplongo
# paradox : paradox
# pilah : pilah
# emil : emil
# diambil : ambil
# jarumnya : jarum
# buka : buka
# gambar : gambar
# pengujian : uji
# sinergi : sinergi
# berpengalaman : alam
# administrasi : administrasi
# kadaluwarsa : kadaluwarsa
# antusiasme : antusiasme
# lingkup : lingkup
# optimistis : optimistis
# hatiku : hati
# gembira : gembira
# bayaran : bayar
# antibodi : antibodi
# terbentuk : bentuk
# parameter : parameter
# tnipolri : tnipolri
# pengiriman : kirim
# tantangan : tantang
# laporkan : lapor
# dipungut : pungut
# pesisir : pesisir
# yogyakarta : yogyakarta
# kasdim : kasdim
# mayor : mayor
# sugeng : sugeng
# riyadi : riyadi
# sindikat : sindikat
# loketcom : loketcom
# serius : serius
# umkm : umkm
# jamin : jamin
# merencanakan : rencana
# modifikasi : modifikasi
# genetik : genetik
# ustadz : ustadz
# maaher : maaher
# to : to
# terjamin : jamin
# keasliannya : asli
# coronavirus : coronavirus
# mentargetkan : target
# jt : jt
# tujuh : tujuh
# diterbitkan : terbit
# mitosmitos : mitosmitos
# kesan : kesan
# somad : somad
# ndak : ndak
# sesakit : sakit
# ditinggal : tinggal
# pas : pas
# sayangsayangnya : sayangsayangnya
# serbuan : serbu
# vaksinmt : vaksinmt
# menurunnya : turun
# global : global
# membuka : buka
# vaccine : vaccine
# tourism : tourism
# utsmaniy : utsmaniy
# pelopor : pelopor
# kenal : kenal
# lelah : lelah
# dievaluasi : evaluasi
# gradika : gradika
# bakti : bakti
# minimal : minimal
# bijak : bijak
# suksesnya : sukses
# komunitas : komunitas
# peran : peran
# strategis : strategis
# akun : akun
# meringankan : ringan
# penyerta : serta
# tradisional : tradisional
# menggantikan : ganti
# keadilan : adil
# jangka : jangka
# berbedabeda : berbedabeda
# berdasarkan : dasar
# pertimbangan : timbang
# presisi : presisi
# berkeadilan : adil
# daya : daya
# magnetis : magnetis
# dikoneksikan : koneksi
# pelatih : latih
# pendukung : dukung
# cabang : cabang
# olah : olah
# raga : raga
# tujuan : tuju
# tercapainya : capa
# normal : normal
# rekrutmen : rekrutmen
# staf : staf
# lab : lab
# rsu : rsu
# mulia : mulia
# tercapai : capai
# penuh : penuh
# fase : fase
# dijalankan : jalan
# sosial : sosial
# adat : adat
# dibedakan : beda
# pencegahannya : cegah
# bahu : bahu
# membahu : bahu
# sigap : sigap
# mari : mari
# rk : rk
# abu : abu
# janda : janda
# faktanya : fakta
# apec : apec
# mewujudkan : wujud
# cukupi : cukup
# diagram : diagram
# komnas : komnas
# gbk : gbk
# tangkal : tangkal
# bidan : bidan
# menghentikan : henti
# poin : poin
# berjalan : jalan
# kera : kera
# afrika : afrika
# targetkan : target
# pembentukan : bentuk
# tahan : tahan
# ingatkan : ingat
# ct : ct
# paruparu : paruparu
# lockdown : lockdown
# timur : timur
# mendarat : darat
# dipasang : pasang
# dajjal : dajjal
# milyard : milyard
# dihindari : hindar
# mtvaksinasi : mtvaksinasi
# terhambat : hambat
# melambat : lambat
# meningkat : tingkat
# drive : drive
# thrue : thrue
# dibohongin : dibohongin
# leukimia : leukimia
# mengerikan : keri
# sekarat : sekarat
# diatas : atas
# satunya : satu
# didunia : dunia
# pemerintahnya : perintah
# bahagia : bahagia
# merelakan : rela
# rakyatnya : rakyat
# pembuat : buat
# himbau : himbau
# penyelenggaraan : selenggara
# kerjasama : kerjasama
# covaxgavi : covaxgavi
# puluhan : puluh
# santri : santri
# kimia : kimia
# tahaptahap : tahaptahap
# menstimulasi : stimulasi
# berhak : hak
# transfeksi : transfeksi
# evaluasi : evaluasi
# kebal : kebal
# luc : luc
# montagnier : montagnier
# fraksi : fraksi
# pdip : pdip
# wapres : wapres
# ajaran : ajar
# mengurus : urus
# sim : sim
# skck : skck
# pengalaman : alam
# enam : enam
# institusi : institusi
# plasma : plasma
# konvalesen : konvalesen
# pengobatan : obat
# alternatif : alternatif
# sektor : sektor
# ekraf : ekraf
# menggeliat : geliat
# proaktif : proaktif
# kedokteran : dokter
# animo : animo
# total : total
# keterbukaan : buka
# akses : akses
# rrt : rrt
# berpartisipasi : partisipasi
# monitoring : monitoring
# jaga : jaga
# kerahasiaan : rahasia
# mungkinkan : mungkin
# pemkot : pemkot
# pekanbaru : pekanbaru
# riau : riau
# menarik : tarik
# tarik : tarik
# ulur : ulur
# finalisasi : final
# roadmap : roadmap
# menghadapi : hadap
# jgn : jgn
# sesuaikan : sesuai
# namanya : nama
# passport : passport
# aksesnya : akses
# dipermudah : mudah
# akurat : akurat
# putus : putus
# mata : mata
# lapisan : lapis
# berdampingan : damping
# aplikasi : aplikasi
# kebocoran : bocor
# keluarga : keluarga
# tercinta : cinta
# sepertiga : tiga
# sdmk : sdmk
# persiapkan : siap
# tua : tua
# henti : henti
# dipercaya : percaya
# diperuntukkan : untuk
# ridwan : ridwan
# kamil : kamil
# rasakan : rasa
# siang : siang
# optimisme : optimisme
# ppni : ppni
# babi : babi
# zombie : zombie
# tripsin : tripsin
# katalisator : katalisator
# produk : produk
# komunikasi : komunikasi
# terstruktur : struktur
# pengungsi : ungsi
# migran : migran
# permudah : mudah
# pelayan : layan
# kenaikan : naik
# matangkan : matang
# kirim : kirim
# blast : blast
# berisikan : risi
# dilemahkan : lemah
# bahanbahan : bahanbahan
# dengue : dengue
# fabiana : fabiana
# souza : souza
# rssao : rssao
# lucas : lucas
# porto : porto
# alegre : alegre
# kekurangan : kurang
# monyet : monyet
# polio : polio
# eul : eul
# persetujuan : tuju
# berguna : guna
# menjad : menjad
# dilahirkan : lahir
# kelainan : lain
# ibunya : ibu
# only : only
# for : for
# clinical : clinical
# trial : trial
# pidato : pidato
# henry : henry
# kissinger : kissinger
# susut : susut
# bertujuan : tuju
# modal : modal
# mixing : mixing
# ekstra : ekstra
# {'mui': 'mui', 'larang': 'larang', 'vaksin': 'vaksin', 'covid': 'covid', 'tiongkok': 'tiongkok', 'menteri': 'menteri', 'agama': 'agama', 'terkena': 'kena', 'hoaks': 'hoaks', 'rakyat': 'rakyat', 'divaksin': 'vaksin', 'mengubah': 'ubah', 'dna': 'dna', 'manusia': 'manusia', 'jawa': 'jawa', 'barat': 'barat', 'daerah': 'daerah', 'disuntik': 'suntik', 'bpom': 'bpom', 'halangi': 'halang', 'penyuntikan': 'sunti', 'berbasis': 'bas', 'mrna': 'mrna', 'rusak': 'rusak', 'masyarakat': 'masyarakat', 'zimbabwe': 'zimbabwe', 'penyakit': 'sakit', 'kulit': 'kulit', 'berair': 'air', 'akibat': 'akibat', 'indonesia': 'indonesia', 'mengalami': 'alami', 'dibunuh': 'bunuh', 'china': 'china', 'mengandung': 'kandung', 'aluminium': 'aluminium', 'merusak': 'rusak', 'otak': 'otak', 'disimpan': 'simpan', 'suhu': 'suhu', 'derajat': 'derajat', 'memanipulasi': 'manipulasi', 'gen': 'gen', 'pendaftaran': 'daftar', 'penerima': 'terima', 'sinovac': 'sinovac', 'juta': 'juta', 'eropa': 'eropa', 'idi': 'idi', 'tolak': 'tolak', 'singapura': 'singapura', 'lakukan': 'laku', 'vaksinasi': 'vaksinasi', 'bandara': 'bandara', 'changi': 'changi', 'formaldehida': 'formaldehida', 'menyebabkan': 'sebab', 'leukemia': 'leukemia', 'anak': 'anak', 'buatan': 'buat', 'memilih': 'pilih', 'impor': 'impor', 'jerman': 'jerman', 'presiden': 'presiden', 'jokowi': 'jokowi', 'perbandingan': 'banding', 'penemuan': 'temu', 'hiv': 'hiv', 'flu': 'flu', 'kanker': 'kanker', 'gratis': 'gratis', 'peserta': 'serta', 'bpjs': 'bpjs', 'aktif': 'aktif', 'beli': 'beli', 'paus': 'paus', 'fransiskus': 'fransiskus', 'masuk': 'masuk', 'surga': 'surga', 'bill': 'bill', 'gates': 'gates', 'ceo': 'ceo', 'pfizer': 'pfizer', 'menolak': 'tolak', 'pemerintah': 'perintah', 'rumania': 'rumania', 'tutup': 'tutup', 'pusat': 'pusat', 'imbas': 'imbas', 'penolakan': 'tolak', 'persen': 'persen', 'warga': 'warga', 'meninggal': 'tinggal', 'dunia': 'dunia', 'website': 'website', 'cdc': 'cdc', 'amerika': 'amerika', 'cacat': 'cacat', 'sakit': 'sakit', 'parah': 'parah', 'pasca': 'pasca', 'ulama': 'ulama', 'aceh': 'aceh', 'haramkan': 'haram', 'nomor': 'nomor', 'rekening': 'rekening', 'ponsel': 'ponsel', 'diblokir': 'blokir', 'joko': 'joko', 'widodo': 'widodo', 'dikabarkan': 'kabar', 'kejangkejang': 'kejangkejang', 'berbahaya': 'bahaya', 'polisorbat': 'polisorbat', 'orang': 'orang', 'menjalani': 'jalan', 'mematuhi': 'patuh', 'protokol': 'protokol', 'kesehatan': 'sehat', 'danramil': 'danramil', 'kebomas': 'kebomas', 'gresik': 'gresik', 'air': 'air', 'kelapa': 'kelapa', 'hijau': 'hijau', 'penawar': 'tawar', 'gagal': 'gagal', 'diulang': 'ulang', 'gereja': 'gereja', 'thailand': 'thailand', 'menangis': 'menang', 'sebabkan': 'sebab', 'lamban': 'lamban', 'berpikir': 'pikir', 'susah': 'susah', 'menghafal': 'hafal', 'who': 'who', 'moderna': 'moderna', 'sistem': 'sistem', 'operasi': 'operasi', 'dirancang': 'rancang', 'agen': 'agen', 'biologis': 'biologis', 'bupati': 'bupati', 'pasuruan': 'pasuruan', 'alami': 'alami', 'suntik': 'suntik', 'meledak': 'ledak', 'kompensasi': 'kompensasi', 'surat': 'surat', 'elektronik': 'elektronik', 'mengatasnamakan': 'mengatasnamakan', 'ipd': 'ipd', 'balitbangkes': 'balitbangkes', 'terkait': 'kait', 'pemberian': 'beri', 'pesan': 'pesan', 'berantai': 'beranta', 'lansia': 'lansia', 'kantor': 'kantor', 'bppsdmk': 'bppsdmk', 'jakarta': 'jakarta', 'potasium': 'potasium', 'organ': 'organ', 'tubuh': 'tubuh', 'data': 'data', 'tim': 'tim', 'medis': 'medis', 'lupa': 'lupa', 'jenis': 'jenis', 'sertifikat': 'sertifikat', 'nondki': 'nondki', 'corona': 'corona', 'senayan': 'senayan', 'whatsapp': 'whatsapp', 'informasi': 'informasi', 'ajakan': 'aja', 'bio': 'bio', 'farma': 'farma', 'mudah': 'mudah', 'terinfeksi': 'infeksi', 'larangan': 'larang', 'minum': 'minum', 'obat': 'obat', 'jantung': 'jantung', 'jadwal': 'jadwal', 'gedung': 'gedung', 'pakuan': 'paku', 'bandung': 'bandung', 'pengumuman': 'umum', 'puskesmas': 'puskesmas', 'kramat': 'kramat', 'jati': 'jati', 'guru': 'guru', 'honorer': 'honorer', 'leles': 'leles', 'garut': 'g ...
# ------------------------
# Pandas Apply: 100%|██████████| 1443/1443 [00:00<00:00, 281741.95it/s]

# %%
datavacc.to_csv("Stemming-justtitle.csv", index=False)

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
import gensim
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
list_accuracy, list_precision, list_recall, list_f1 = [], [], [], []

# %%
#split data use ratio 80:20

for i in range(5):
    # split dataset
    train, test = train_test_split(datavacc, test_size=0.2)

    # model gensim word2vec
    w2v_model = gensim.models.Word2Vec(train['judul'], vector_size=100, window=5, min_count=2) 

    # display word vectors for each word in the sentence
    words = set(w2v_model.wv.index_to_key)
    x_train_vect = np.array(([np.array([w2v_model.wv[i] for i in ls if i in words])
                            for ls in train['judul']]), dtype='object')

    x_test_vect = np.array(([np.array([w2v_model.wv[i] for i in ls if i in words])
                            for ls in test['judul']]), dtype='object')


    # calculate the sentence vector by averaging the word vector in the sentence
    x_train_vect_avg = []
    for v in x_train_vect:
        if v.size:
            x_train_vect_avg.append(v.mean(axis=0))
            
        else:
            x_train_vect_avg.append(np.zeros(100, dtype=float))

    x_test_vect_avg = []
    for v in x_test_vect:
        if v.size:
            x_test_vect_avg.append(v.mean(axis=0))
        else:
            x_test_vect_avg.append(np.zeros(100, dtype=float))

    # length of train and test average vector
    print(len(x_train_vect_avg), len(x_test_vect_avg))

    x_train_vect_avg = pd.DataFrame(x_train_vect_avg)

    x_test_vect_avg = pd.DataFrame(x_test_vect_avg)

    y_train = train['label']
    y_test = test['label']

    # instantiating the random over sampler 
    ros = RandomOverSampler()
    # resampling X, y
    x_train_ros, y_train_ros = ros.fit_resample(x_train_vect_avg, y_train)
    # new class distribution 
    print(Counter(y_train_ros))

    
    # grid parameters for random forest
    parameters = {
        'n_estimators' : [50, 75, 100], 
        'min_samples_leaf' : [1, 2, 4],
        'min_samples_split' : [2, 5, 10]
    }

    # k-fold method cross validation
    kf=KFold(n_splits=5, shuffle=False) 
    model_rf = RandomForestClassifier(random_state=49)
    clf = GridSearchCV(model_rf,                    # model
                    param_grid = parameters,   # hyperparameters
                    scoring='accuracy',        # metric for scoring
                    cv=kf)                     # number of folds

    # train model
    clf.fit(x_train_ros,y_train_ros)
    
    print("Tuned Hyperparameters :", clf.best_params_)
    print("Best Accuracy :",clf.best_score_)

    # looking for the best parameters
    best_parameters = clf.best_params_

    # classification RF
    y_pred_rf = clf.predict(x_test_vect_avg)
    presisi = precision_score(y_test, y_pred_rf) 
    recall = recall_score(y_test, y_pred_rf) 
    accuracy = accuracy_score(y_test, y_pred_rf)
    f1 = f1_score(y_test, y_pred_rf)
    print('Precision Test: {} / Recall Test: {} / Accuracy Test: {} / F1 Test: {}'.format( 
        round(presisi, 4), round(recall, 4), round(accuracy, 4), round(f1, 4)))

    # list of evaluation metric values
    list_accuracy.append(accuracy)
    list_precision.append(presisi)
    list_recall.append(recall)
    list_f1.append(f1)
# Out:
# 1154 289
# Counter({1: 815, 0: 815})
# Tuned Hyperparameters : {'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 75}
# Best Accuracy : 0.8625766871165645
# Precision Test: 0.4857 / Recall Test: 0.3505 / Accuracy Test: 0.6574 / F1 Test: 0.4072
# 1154 289
# Counter({1: 802, 0: 802})
# Tuned Hyperparameters : {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# Best Accuracy : 0.8529478193146417
# Precision Test: 0.5606 / Recall Test: 0.4405 / Accuracy Test: 0.737 / F1 Test: 0.4933
# 1154 289
# Counter({0: 823, 1: 823})
# Tuned Hyperparameters : {'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 75}
# Best Accuracy : 0.8687980105001382
# Precision Test: 0.5231 / Recall Test: 0.3238 / Accuracy Test: 0.6471 / F1 Test: 0.4
# 1154 289
# Counter({0: 826, 1: 826})
# Tuned Hyperparameters : {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Accuracy : 0.8560212395861944
# Precision Test: 0.5857 / Recall Test: 0.3796 / Accuracy Test: 0.6678 / F1 Test: 0.4607
# 1154 289
# Counter({0: 815, 1: 815})
# Tuned Hyperparameters : {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Accuracy : 0.8404907975460123
# Precision Test: 0.6176 / Recall Test: 0.433 / Accuracy Test: 0.7197 / F1 Test: 0.5091

# %%
print(list_accuracy, np.mean(list_accuracy)) 
print(list_precision, np.mean(list_precision))
print(list_recall, np.mean(list_recall))
print(list_f1, np.mean(list_f1))
# Out:
# [0.657439446366782, 0.7370242214532872, 0.6470588235294118, 0.6678200692041523, 0.7197231833910035] 0.6858131487889273
# [0.4857142857142857, 0.5606060606060606, 0.5230769230769231, 0.5857142857142857, 0.6176470588235294] 0.5545517227870169
# [0.35051546391752575, 0.44047619047619047, 0.3238095238095238, 0.37962962962962965, 0.4329896907216495] 0.38548409971090386
# [0.40718562874251496, 0.4933333333333333, 0.4, 0.46067415730337086, 0.509090909090909] 0.45405680569402557

# %% [markdown]
# Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
list_accuracy_Adb, list_precision_Adb, list_recall_Adb, list_f1_Adb = [], [], [], []

# %%
for i in range(5):
    # split dataset
    train, test = train_test_split(datavacc, test_size=0.2)

     # model gensim word2vec
    w2v_model = gensim.models.Word2Vec(train['judul'], vector_size=100, window=5, min_count=2)

   # display word vectors for each word in the sentence
    words = set(w2v_model.wv.index_to_key)
    x_train_vect = np.array(([np.array([w2v_model.wv[i] for i in ls if i in words])
                            for ls in train['judul']]), dtype='object')

    x_test_vect = np.array(([np.array([w2v_model.wv[i] for i in ls if i in words])
                            for ls in test['judul']]), dtype='object')

    # calculate the sentence vector by averaging the word vector in the sentence
    x_train_vect_avg = []
    for v in x_train_vect:
        if v.size:
            x_train_vect_avg.append(v.mean(axis=0))
            
        else:
            x_train_vect_avg.append(np.zeros(100, dtype=float))

    x_test_vect_avg = []
    for v in x_test_vect:
        if v.size:
            x_test_vect_avg.append(v.mean(axis=0))
        else:
            x_test_vect_avg.append(np.zeros(100, dtype=float))


    # length of train and test average vector
    print(len(x_train_vect_avg), len(x_test_vect_avg))

    x_train_vect_avg = pd.DataFrame(x_train_vect_avg)

    x_test_vect_avg = pd.DataFrame(x_test_vect_avg)

    y_train = train['label']
    y_test = test['label']

    # instantiating the random over sampler 
    ros = RandomOverSampler()
    # resampling X, y
    x_train_ros, y_train_ros = ros.fit_resample(x_train_vect_avg, y_train)
    # new class distribution 
    print(Counter(y_train_ros))

    
    # parameter grid for Adaboost
    parameters = {
        'n_estimators' : [100, 150],
        'learning_rate' : [0.5, 0.01, 0.2, 0.3, 0.4]
    }

    # k-fold method cross validation
    kf=KFold(n_splits=5, shuffle=False) 
    model_adaboost = AdaBoostClassifier(random_state=49)
    clfdaboost = GridSearchCV(model_adaboost,                    # model
                    param_grid = parameters,   # hyperparameters
                    scoring='accuracy',        # metric for scoring
                    cv=kf)                     # number of folds

    # train model
    clfdaboost.fit(x_train_ros,y_train_ros)
    
    print("Tuned Hyperparameters adaboost:", clfdaboost.best_params_)
    print("Best Accuracy adaboost :",clfdaboost.best_score_)

    # looking for the best parameters
    best_parameters = clf.best_params_

    # classification Adaboost

    y_pred_adb = clfdaboost.predict(x_test_vect_avg)
    presisi = precision_score(y_test, y_pred_adb) 
    recall = recall_score(y_test, y_pred_adb) 
    accuracy = accuracy_score(y_test, y_pred_adb)
    f1 = f1_score(y_test, y_pred_adb)
    print('Precision Test: {} / Recall Test: {} / Accuracy Test: {} / F1 Test: {}'.format( 
        round(presisi, 4), round(recall, 4), round(accuracy, 4), round(f1, 4)))

    # list of evaluation metric values
    list_accuracy_Adb.append(accuracy)
    list_precision_Adb.append(presisi)
    list_recall_Adb.append(recall)
    list_f1_Adb.append(f1)
# Out:
# 1154 289
# Counter({0: 815, 1: 815})
# Tuned Hyperparameters adaboost: {'learning_rate': 0.5, 'n_estimators': 150}
# Best Accuracy adaboost : 0.7607361963190183
# Precision Test: 0.5474 / Recall Test: 0.5361 / Accuracy Test: 0.6955 / F1 Test: 0.5417
# 1154 289
# Counter({0: 818, 1: 818})
# Tuned Hyperparameters adaboost: {'learning_rate': 0.5, 'n_estimators': 150}
# Best Accuracy adaboost : 0.761020362497203
# Precision Test: 0.5743 / Recall Test: 0.58 / Accuracy Test: 0.7059 / F1 Test: 0.5771
# 1154 289
# Counter({0: 807, 1: 807})
# Tuned Hyperparameters adaboost: {'learning_rate': 0.5, 'n_estimators': 150}
# Best Accuracy adaboost : 0.7645520450743226
# Precision Test: 0.5667 / Recall Test: 0.573 / Accuracy Test: 0.7336 / F1 Test: 0.5698
# 1154 289
# Counter({1: 809, 0: 809})
# Tuned Hyperparameters adaboost: {'learning_rate': 0.5, 'n_estimators': 150}
# Best Accuracy adaboost : 0.754676451477277
# Precision Test: 0.5149 / Recall Test: 0.5714 / Accuracy Test: 0.6955 / F1 Test: 0.5417
# 1154 289
# Counter({0: 803, 1: 803})
# Tuned Hyperparameters adaboost: {'learning_rate': 0.5, 'n_estimators': 150}
# Best Accuracy adaboost : 0.7416149068322981
# Precision Test: 0.5421 / Recall Test: 0.6824 / Accuracy Test: 0.737 / F1 Test: 0.6042

# %%
print(list_accuracy_Adb, np.mean(list_accuracy_Adb))
print(list_precision_Adb, np.mean(list_precision_Adb))
print(list_recall_Adb, np.mean(list_recall_Adb))
print(list_f1_Adb, np.mean(list_f1_Adb))
# Out:
# [0.6955017301038062, 0.7058823529411765, 0.7335640138408305, 0.6955017301038062, 0.7370242214532872] 0.7134948096885814
# [0.5473684210526316, 0.5742574257425742, 0.5666666666666667, 0.5148514851485149, 0.5420560747663551] 0.5490400146753485
# [0.5360824742268041, 0.58, 0.5730337078651685, 0.5714285714285714, 0.6823529411764706] 0.588579538939403
# [0.5416666666666666, 0.5771144278606964, 0.5698324022346368, 0.5416666666666666, 0.6041666666666666] 0.5668893660190666
